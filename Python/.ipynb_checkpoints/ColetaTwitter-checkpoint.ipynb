# %% [markdown]
# # <font color=blue> Coleta de dados e análise de sentimento no Twitter </font>

# %% [markdown]
# Esse projeto consiste na Análise de sentimentos de tweets coletados através da API do Twitter sobre X. O projeto consiste em:
# * Coleta de tweets.
# * Identificação de tweets mais curtidos e retweetados.
# * Identificação da fonte dos tweets.
# * Análise de sentimentos.
# * Nuvem de palavras mais frequentes.
# * Séries de tweets no tempo.
# * Mapa de calor dos tweets utilizando a localização declarada pelos usuários.

# %% [markdown]
# ### <font color=blue>Importação de pacotes</font>

# %%
# Pacotes básico
import tweepy #Acessa API do Twitter
import pandas as pd     
import numpy as np 
from textblob import TextBlob as tb
import time
import re
import json
import pymongo

# Pacotes para visualização 
import matplotlib.pyplot as plt

#MAPA
from geopy.geocoders import Nominatim
import folium
from folium import plugins
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### <font color=blue>Definição das credenciais de acesso (autenticação) na API do Twitter</font>

# %%
# Credenciais para utilização da API do Twitter

consumer_key = "ThjEtKexjpxXSEFdIskFAJIa1"
consumer_secret = "xVAOsFNAov5zBeToU6pQlTVGOGFY3yhaSdChzmAIq1LLFvNAs2"
access_token = "989683030229995521-lKpEaaN5RMMpJg99BIN0x4KFdEvJjde"
access_token_secret = "M9ibsxsupWqJ7Aby2FXtsPidLvrvmUIwTtNxDhXDDlO6Q"

# %% [markdown]
# ### <font color=blue>Autenticação na API do Twitter</font>

# %%
#Realizar autenticação no Twitter

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True,retry_count=5)

# %% [markdown]
# **parâmetros:**
# * retry_count - número padrão de tentativas para tentar quando ocorrer um erro
# * retry_delay - número de segundos para aguardar entre tentativas
# * wait_on_rate_limit - se deve ou não esperar automaticamente a reposição dos limites de taxa
# * wait_on_rate_limit_notify - Imprima ou não uma notificação quando o Tweepy estiver aguardando a reposição dos limites de taxa

# %% [markdown]
# ### <font color=blue>Coleta de dados (busca por palavra chave)</font>

# %%
# Definir listas de armazenamento
tweets = []
info = []

#Definir que palavra deseja pesquisar no Twitter
#keyword = ('home office OR trabalho remoto OR trabalho em casa OR homeoffice OR trabalhoremoto OR trabalhoemcasa OR HomeOffice')
keyword = ("covid-19  OR  covid  OR  coronavirus OR pandemic")

# %% [markdown]
# **OBSERVAÇÃO:**
# A documentação completa do pacote *tweepy* está disponível no link abaixo:
# * http://docs.tweepy.org/en/v3.5.0/api.html

# %% [markdown]
# Para realizar a busca por palavra chave vamos utilizar a função abaixo:<br>
# * <font color=green>API.search(q[, lang][, locale][, rpp][, page][, since_id][, geocode][, show_user])</font><br><br>
# **onde os principais parâmetros que serão usados são:**
#
# * <font color=blue>q</font> - a string de consulta de pesquisa
# * <font color=blue>lang</font> - Restringe os tweets para o idioma especificado, fornecido por um código ISO 639-1.
# * <font color=blue>rpp</font> - O número de tweets a serem retornados por página, até no máximo 100.
# * <font color=blue>page</font> - O número da página (começando em 1) a ser retornado, até um máximo de aproximadamente 1500 resultados (com base na página rpp).
# * <font color=blue>since_id</font>  - Retorna apenas status com um ID maior que (ou seja, mais recente que) o ID especificado.
# * <font color=blue>geocode</font>  - Retorna tweets de usuários localizados em um determinado raio da latitude / longitude especificada.
# * <font color=blue>show_user</font>  - Quando verdadeiro, precede "<user>:" no início do tweet. O padrão é falso.

# %% [markdown]
# #####  <font color=red>Exemplo básico para busca por palavra chave e recuperar os tweets em português.</font>

# %%
from googletrans import Translator
from unidecode import unidecode

polaritiesPT = []

for tweetpt in tweepy.Cursor(api.search,q=keyword, tweet_mode='extended',
                           rpp=5, result_type="popular",lang="pt",
                           include_entities=True).items(5):
    #Texto do Tweet
    textPT = unidecode(tweetpt.full_text)
    print('** Tweet em português: '+textPT)
    #Traduzindo para o Inglês
    textEN = Translator().translate(textPT)
    print('** Tweet traduzido:')
    print(textEN.text)
    #Calculando a polaridade do texto traduzido
    polarityPT = tb(textEN.text).sentiment.polarity #analisa a polaridade

    polaritiesPT.append(polarityPT)
    print('\n')
# Out:
# ** Tweet em português: Minha mae, tia, vo e meu vo foram diagnosticados com COVID-19. Foram medicados com hidroxicloroquina ja nos sintomas iniciais da doenca. Nao chegaram a sentir falta de ar e hoje, com seguranca, afirmo que estao recuperados. So tenho a agradecer aos profissionais de saude e a Deus
# ** Tweet traduzido:
# My mother, aunt, and my vo vo were diagnosed with COVID-19. They were treated with hydroxychloroquine already in the initial symptoms of disease. They not come to experience shortness of breath and now, safely, say who are recovered. So I have to thank the health professionals and God
#
#
# ** Tweet em português: Aquela sindrome respiratoria aguda grave que parece COVID, espalha como COVID e mata como COVID continua atacando Minas Gerais, que continua nao fazendo testes. Com a diferenca que 85% dos leitos de COVID de BH tao lotados. Mas era exagero.
#
# https://t.co/X4iwNvO2o8
# ** Tweet traduzido:
# That severe acute respiratory syndrome which seems COVID, such as spreads and kills COVID as COVID continues attacking Minas Gerais, which is still not running tests. With the difference that 85% of BH COVID beds so crowded. But it was overkill.
#
# https://t.co/X4iwNvO2o8
#
#
# ** Tweet em português: Coronavirus, invasao de gafanhotos e Bolsonaro presidente.
#
# E muito problema pra lidar de uma vez so;
# ** Tweet traduzido:
# Coronavirus, invasion of locusts and Bolsonaro president.
#
# And a lot of trouble to deal once only;
#
#
# ** Tweet em português: ATENCAO!!! De acordo com a Universidade Johns Hopkings, Brasil assume 1deg lugar no mundo de curados por Covid-19 com 660,4 mil pessoas, ultrapassando os EUA. Espalhem a noticia porque a extrema-imprensa jamais divulgara essa informacao!!!
# ** Tweet traduzido:
# ATTENTION!!! According to the Johns Hopkings, Brazil takes place in the world 1deg cured by Covid-19 with 660,400 people, surpassing the US. Spread the news because never far press divulged this information !!!
#
#
# ** Tweet em português: No comeco o Congresso funcionaria VIRTUALMENTE so para votar materias de combate ao COVID.
#
# Com o passar do tempo materias nao unanimes passaram a ser votadas.
#
# Agora estamos diante de um grande debate. Nao e justo sequer votar o PL 2630 nestas condicoes.
# #SenadoArquivaPL2630
# ** Tweet traduzido:
# At first Congress work VIRTUALLY so voting materials to combat COVID.
#
# Over time materials not unanimous began to be voted on.
#
# Now we are facing a great debate. It is not fair even vote PL 2630 in these conditions.
# # SenadoArquivaPL2630

# %%
print('Vetor de polaridade:',polaritiesPT)
# Out:
# Vetor de polaridade: [0.25, 0.3, -0.1, -0.09765625, 0.23333333333333336]

# %%
print('MÉDIA DE SENTIMENTO: ' + str(np.mean(polaritiesPT))) #a função mean() pertence ao pacote numpy
# Out:
# MÉDIA DE SENTIMENTO: 0.11713541666666669

# %% [markdown]
# ##  <font color=blue>Buscar por palavra chave e recuperar os tweets em inglês</font>

# %%
#tweets = token.search(q=keyword,count=2000,result_type='mixed',tweet_mode='extended',Lang='en')

# %%
# Para verificar a quantidade de tweets coletado use a função "len()"

#print("Total de tweets coletados %s." % (len(tweets)))

# %%
datasetPathJson = 'C:/Users/JoaoLott/Desktop/Git/ColetaDeDados_BootcampIGTI/DataSets/JSON'
datasetPathTxT = 'C:/Users/JoaoLott/Desktop/Git/ColetaDeDados_BootcampIGTI/DataSets/TXT'

for tweet in tweepy.Cursor(api.search,
                           q=keyword, tweet_mode='extended',
                           rpp=100, result_type="mixed",lang='en',
                           include_entities=True).items(1):
    
    #Grava os dados em um arquivo Json
    with open(datasetPathJson+'\\tweets_covid.json', 'a', encoding='utf8') as filename:    #aberto em mode de append
        
        status = tweet
        
        #converte para string        
        json_str = json.dumps(status._json)
        
        #deserializa a string para um objeto python do tipo dict        
        parsed = json.loads(json_str)
        
        #grava o tweet deserializado no arquivo
        json.dump(parsed, filename, ensure_ascii=False, sort_keys=True, indent=4, separators=(',', ':'))
        
    #Grava os dados no MongoDB
    #Conexão ao banco de dados
    con = pymongo.MongoClient('localhost', 27017)

    #seleciona o banco de dados
    db = con.twitterdb
    
    #seleciona a coleção para armazenar os tweets
    collection = db.tweets_Covid
    
    #insere os dados
    #i = 0
    db.tweets_Covid.insert_one(tweet._json)
    #i=i+1
    
    #print("Quantidade de tweets inseridos: %s" % i)
    
    #Grava os dados em um arquivo TXT
    if 'retweeted_status' in dir(tweet):
        aux=tweet.retweeted_status.full_text
    else:
        aux=tweet.full_text
        
    newtweet = aux.replace("\n", " ")
   
    tweets.append(newtweet)
    info.append(tweet)
    
    #Salva os tweets em um arquivo txt
    file = open(datasetPathTxT+'\\tweets_covid.txt', 'a', -1, 'utf-8')    
    file.write(newtweet+'\n')
    file.close()
    
    
    #time.sleep(120)

# %%
print("Total de tweets coletados %s." % (len(tweets)))
# Out:
# Total de tweets coletados 326.

# %% [markdown]
# ### <font color=blue>Criar dataframe</font>

# %%
tweets_df = pd.DataFrame(tweets, columns=['Tweets']) 

tweets_df['len']  = np.array([len(tweet) for tweet in tweets])
tweets_df['ID']   = np.array([tweet.id for tweet in info])
tweets_df['USER']   = np.array([tweet.user.screen_name for tweet in info])
tweets_df['userName'] = np.array([tweet.user.name for tweet in info])
tweets_df['User Location']    = np.array([tweet.user.location for tweet in info])
tweets_df['Language'] = np.array([tweet.user.lang for tweet in info])
tweets_df['Date'] = np.array([tweet.created_at for tweet in info])
tweets_df['Source'] = np.array([tweet.source for tweet in info])
tweets_df['Likes']  = np.array([tweet.favorite_count for tweet in info])
tweets_df['Retweets']    = np.array([tweet.retweet_count for tweet in info])
tweets_df['Geo']    = np.array([tweet.geo for tweet in info])
tweets_df['Coordinates']    = np.array([tweet.coordinates for tweet in info])         
tweets_df['Place']    = np.array([tweet.place for tweet in info])

# %% [markdown]
# **Exportar para csv**

# %%
datasetPathCSV = 'C:/Users/JoaoLott/Desktop/Git/ColetaDeDados_BootcampIGTI/DataSets/CSV'

tweets_df.to_csv(datasetPathCSV+'//tweets_Keyword_covid_100.csv')

# %%
tweets_df.head(3)
# Out:
#                                               Tweets  len  \
# 0  This woman on the news just said, imagine if t...  184
# 1  Numbers are going in the wrong direction.   Ye...  216
# 2  The Trump admin. plans to end federal funding ...  159
#
#                     ID             USER     userName User Location Language  \
# 0  1275808300119064577  JasmynBeKnowing       Jasmyn           LA      None
# 1  1275826656050122753       jaketapper  Jake Tapper                   None
# 2  1275823820448976897          CNBCnow     CNBC Now                   None
#
#                  Date                Source   Likes  Retweets   Geo  \
# 0 2020-06-24 15:09:36       Twitter Web App  315860     84423  None
# 1 2020-06-24 16:22:33    Twitter for iPhone    2231      1238  None
# 2 2020-06-24 16:11:17  Twitter Media Studio   15043     16039  None
#
#   Coordinates Place
# 0        None  None
# 1        None  None
# 2        None  None

# %% [markdown]
# ### Identificar Top Tweets coletados

# %%
# Tweets com maior número de LIKES
likes_max = np.max(tweets_df['Likes']) #Função max do numpy identifica o valor máximo

likes = tweets_df[tweets_df.Likes == likes_max].index[0] #pega o primeiro tweet com valor máximo de curtidas

print("O tweet com mais curtidas (likes) é: \n{}".format(tweets_df['Tweets'][likes]))
print("Número de curtidas: {}".format(likes_max))
# Out:
# O tweet com mais curtidas (likes) é:
# Actually you just got ROCKED by teens on TikTok who flooded the Trump campaign w/ fake ticket reservations &amp; tricked you into believing a million people wanted your white supremacist open mic enough to pack an arena during COVID  Shout out to Zoomers. Y’all make me so proud. ☺️ https://t.co/jGrp5bSZ9T
# Número de curtidas: 613995

# %%
print(np.sum(tweets_df['Likes'] == likes_max)) #conta quantos tweets possuem o mesmo valor máximo de curtidas
# Out:
# 2

# %%
retweet_max  = np.max(tweets_df['Retweets']) #retorna o valor máximo

retweet  = tweets_df[tweets_df.Retweets == retweet_max].index[0] #pega o primeiro tweet com valor máximo de Retweets

print("O tweet com mais retweet é: \n{}".format(tweets_df['Tweets'][retweet]))
print("Número de retweets: {}".format(retweet_max))
# Out:
# O tweet com mais retweet é:
# Actually you just got ROCKED by teens on TikTok who flooded the Trump campaign w/ fake ticket reservations &amp; tricked you into believing a million people wanted your white supremacist open mic enough to pack an arena during COVID  Shout out to Zoomers. Y’all make me so proud. ☺️ https://t.co/jGrp5bSZ9T
# Número de retweets: 115752

# %%
print(np.sum(tweets_df['Retweets'] == retweet_max)) #conta quantos tweets possuem o mesmo valor máximo de Retweets
# Out:
# 3

# %% [markdown]
# ### Identifica a fonte(origem) do tweet
#
# A fonte neste caso é o app ou dispositivo onde o usuário postou o tweet

# %%
sources = [] #lista para armazenar a fontes
for source in tweets_df['Source']:
    if source not in sources:
        sources.append(source) #inclui no vetor sources apenas se a fonte encontrada ainda não foi incluída

percent = np.zeros(len(sources)) #Retorna um novo vetor, com o número de elementos do vetor sources, preenchido com zeros

for source in tweets_df['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

# %% [markdown]
# ##### Gráfico que exibe o número de tweets por fonte

# %%
sourceDF = pd.DataFrame({
 'source':percent,
}, index=sources)

sourceDF
# Out:
#                                 source
# Twitter Web App                  102.0
# Twitter for iPhone               136.0
# Twitter Media Studio              13.0
# SocialFlow                        21.0
# Twitter for iPad                   9.0
# TweetDeck                         18.0
# Buffer                             3.0
# Wildmoka                           3.0
# Twitter Media Studio - LiveCut     3.0
# Twitter for Android                9.0
# Sprout Social                      3.0
# SocialNewsDesk                     6.0

# %%
sources_sorted = sourceDF.sort_values('source',ascending=True)
ax = sources_sorted.source.plot(kind='barh',color='#A52A2A')
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# %%
sources_sorted = sourceDF.sort_values('source',ascending=False)
ax = sources_sorted.source.plot(kind='barh',color='#B8860B')
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# %% [markdown]
# **Dica:**
# Veja relação de cores em HTML em:
# * https://www.w3schools.com/tags/ref_colornames.asp

# %% [markdown]
# ## <font color=red>Análise de polaridade:</font>

# %%
#Variável que irá armazenar as polaridades
analysis = None

# Lista vazia para armazenar as polaridades
polarities = []

# %%
tweets_df.head(1)
# Out:
#                                               Tweets  len  \
# 0  This woman on the news just said, imagine if t...  184
#
#                     ID             USER userName User Location Language  \
# 0  1275808300119064577  JasmynBeKnowing   Jasmyn           LA      None
#
#                  Date           Source   Likes  Retweets   Geo Coordinates  \
# 0 2020-06-24 15:09:36  Twitter Web App  315860     84423  None        None
#
#   Place
# 0  None

# %% [markdown]
# ##### Calcula polaridade (sentiment.polarity)

# %%
for tweet in tweets_df['Tweets']: #para cada tweet    
    analysis = tb(tweet)   
    
    polarity = analysis.sentiment.polarity #analisa a polaridade

    polarities.append(polarity)

# %% [markdown]
# **ou**

# %%
for tweet in tweets_df['Tweets']: #para cada tweet    
    #analysis = tb(tweet)   
   
    polarity = tb(tweet).sentiment.polarity #analisa a polaridade

    polarities.append(polarity)

# %%
tweets_df.head(3)
# Out:
#                                               Tweets  len  \
# 0  This woman on the news just said, imagine if t...  184
# 1  Numbers are going in the wrong direction.   Ye...  216
# 2  The Trump admin. plans to end federal funding ...  159
#
#                     ID             USER     userName User Location Language  \
# 0  1275808300119064577  JasmynBeKnowing       Jasmyn           LA      None
# 1  1275826656050122753       jaketapper  Jake Tapper                   None
# 2  1275823820448976897          CNBCnow     CNBC Now                   None
#
#                  Date                Source   Likes  Retweets   Geo  \
# 0 2020-06-24 15:09:36       Twitter Web App  315860     84423  None
# 1 2020-06-24 16:22:33    Twitter for iPhone    2231      1238  None
# 2 2020-06-24 16:11:17  Twitter Media Studio   15043     16039  None
#
#   Coordinates Place
# 0        None  None
# 1        None  None
# 2        None  None

# %%
print('Vetor de polaridade:',polarities)
# Out:
# Vetor de polaridade: [0.0, -0.003409090909090917, 0.0, -0.16875, 0.0, -0.003409090909090917, 0.0, -0.16875, 0.1481818181818182, -0.0875, 0.13333333333333333, -0.08636363636363638, -0.12499999999999999, 0.14424242424242426, 0.0, 0.029523809523809525, -0.1638888888888889, 0.11468253968253969, 0.0, -0.16666666666666666, -0.09999999999999998, 0.033333333333333326, 0.0, 0.46875, 0.13636363636363635, 0.0, -0.1375, 0.1, -0.05, -0.14166666666666666, 0.033333333333333326, 0.0, 0.0, 0.75, 0.0, -0.3, 0.0, 0.0, 0.0, 0.22499999999999998, 0.4916666666666667, 0.0, 0.14285714285714285, -0.175, 0.3, -0.4, 0.016666666666666673, 0.11632653061224489, -0.0462962962962963, 0.5, 0.16666666666666666, -0.24242424242424243, 0.13636363636363635, 0.13636363636363635, 0.14069264069264067, -0.034375, 0.8125, -0.24444444444444446, 0.05909090909090909, 0.2, -0.125, -0.12121212121212122, 0.27510822510822514, 0.03125, 0.0, 0.0, 0.03968253968253968, 0.3, -0.125, -0.20833333333333326, 0.6, -0.031111111111111128, 0.0, -0.0888888888888889, 0.32246753246753246, 0.0, 0.05000000000000001, 0.1880952380952381, -0.18055555555555555, 0.09166666666666667, -0.003124999999999989, -0.5, 0.1, 0.18240740740740738, 0.0, 0.13636363636363635, 0.10909090909090909, 0.0, 0.11363636363636363, -0.2, 0.0, 0.0, -0.08, 0.2, -0.007954545454545452, 0.3333333333333333, 0.0, -0.6, 0.875, -0.45, 0.48, 0.14444444444444446, -0.15000000000000002, 0.4, 0.4, 0.10416666666666667, -0.1, 0.0, -0.16666666666666666, -0.2833333333333333, 0.0, 0.0, -0.003409090909090917, 0.0, -0.16875, 0.1481818181818182, -0.0875, 0.13333333333333333, -0.08636363636363638, -0.12499999999999999, 0.14424242424242426, 0.0, 0.029523809523809525, -0.1638888888888889, 0.11468253968253969, 0.0, -0.16666666666666666, -0.09999999999999998, 0.033333333333333326, 0.0, 0.46875, 0.13636363636363635, 0.0, -0.1375, 0.1, -0.05, -0.14166666666666666, 0.033333333333333326, 0.0, 0.0, 0.75, 0.0, -0.3, 0.0, 0.0, 0.0, 0.22499999999999998, 0.4916666666666667, 0.0, 0.14285714285714285, -0.175, 0.3, -0.4, 0.016666666666666673, 0.11632653061224489, -0.0462962962962963, 0.5, 0.16666666666666666, -0.24242424242424243, 0.13636363636363635, 0.13636363636363635, 0.14069264069264067, -0.034375, 0.8125, -0.24444444444444446, 0.05909090909090909, 0.2, -0.125, -0.12121212121212122, 0.27510822510822514, 0.03125, 0.0, 0.0, 0.03968253968253968, 0.3, -0.125, -0.20833333333333326, 0.6, -0.031111111111111128, 0.0, -0.0888888888888889, 0.32246753246753246, 0.0, 0.05000000000000001, 0.1880952380952381, -0.18055555555555555, 0.09166666666666667, -0.003124999999999989, -0.5, 0.1, 0.18240740740740738, 0.0, 0.13636363636363635, 0.10909090909090909, 0.0, 0.11363636363636363, -0.2, 0.0, 0.0, -0.08, 0.2, -0.007954545454545452, 0.3333333333333333, 0.0, -0.6, 0.875, -0.45, 0.48, 0.14444444444444446, -0.15000000000000002, 0.4, 0.4, 0.10416666666666667, -0.1, 0.0, -0.16666666666666666, -0.2833333333333333, 0.0, 0.0, -0.003409090909090917, 0.0, -0.16875, 0.1481818181818182, -0.0875, 0.13333333333333333, -0.08636363636363638, -0.12499999999999999, 0.14424242424242426, 0.0, 0.029523809523809525, -0.1638888888888889, 0.11468253968253969, 0.0, -0.16666666666666666, -0.09999999999999998, 0.033333333333333326, 0.0, 0.46875, 0.13636363636363635, 0.0, -0.1375, 0.1, -0.05, -0.14166666666666666, 0.033333333333333326, 0.0, 0.0, 0.75, 0.0, -0.3, 0.0, 0.0, 0.0, 0.22499999999999998, 0.4916666666666667, 0.0, 0.14285714285714285, -0.175, 0.3, -0.4, 0.016666666666666673, 0.11632653061224489, -0.0462962962962963, 0.5, 0.16666666666666666, -0.24242424242424243, 0.13636363636363635, 0.13636363636363635, 0.14069264069264067, -0.034375, 0.8125, -0.24444444444444446, 0.05909090909090909, 0.2, -0.125, -0.12121212121212122, 0.27510822510822514, 0.03125, 0.0, 0.0, 0.03968253968253968, 0.3, -0.125, -0.20833333333333326, 0.6, -0.031111111111111128, 0.0, -0.0888888888888889, 0.32246753246753246, 0.0, 0.05000000000000001, 0.1880952380952381, -0.18055555555555555, 0.09166666666666667, -0.00312499999999998 ...

# %% [markdown]
# ## <font color=red>Análise de Sentimentos:</font>

# %%
print('Para a(s) palavra(s):"%s"' % keyword)
print('A MÉDIA DE SENTIMENTO É: ' + str(np.mean(polarities)))
# Out:
# Para a(s) palavra(s):"covid-19  OR  covid  OR  coronavirus OR pandemic"
# A MÉDIA DE SENTIMENTO É: 0.04473128682594064

# %%
positive = 0
negative = 0
neutral = 0

for polarity in polarities:
    if polarity > 0:
        positive = positive+1
    elif polarity < 0:
        negative = negative+1
    else:
        neutral = neutral+1

# %%
print("Tweets Positivos: %s" % positive)
print("Tweets Negativos: %s" % negative)
print("Tweets Neutros: %s" % neutral)
# Out:
# Tweets Positivos: 282
# Tweets Negativos: 220
# Tweets Neutros: 150

# %%
#calcula percentual
pos_pct=positive*100/len(polarities)
neg_pct=negative*100/len(polarities)
neu_pct=neutral*100/len(polarities)

# %%
sentiments = ['Positivos', 'Negativos','Neutros']
percents = [pos_pct, neg_pct, neu_pct]

# %%
pie_chart = pd.Series(percents, index=sentiments,name='Sentimentos')
pie_chart.plot.pie(fontsize=12, autopct='%.2f', figsize=(5, 5),title="Análise de Sentimentos tweets");

# %%
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',        shadow=True, startangle=90)
explode = (0.1, 0, 0) #Separa o primeiro

pie_chart = pd.Series(percents, index=sentiments,name='')
pie_chart.plot.pie(fontsize=12, explode=explode, autopct='%.2f%%', shadow=True, figsize=(7, 7),title="Análise de Sentimentos tweets");

# %% [markdown]
# **Dica:**
# Veja a documentação do pacote *Matplotlib* no link:
# * https://matplotlib.org/3.1.1/contents.html#

# %% [markdown]
# ### <font color=blue>Mapa de calor dos tweets</font>

# %%
geolocator = Nominatim(user_agent="TweeterSentiments")

latitude = []
longitude = []

for user_location in tweets_df['User Location']:
    try:
        location = geolocator.geocode(user_location)
        latitude.append(location.latitude)
        longitude.append(location.longitude)
    except:
        continue

# %% [markdown]
# **Dica:** Veja a documentação da função *Nominatim* no link:
#
# * https://geopy.readthedocs.io/en/stable/#nominatim

# %%
coordenadas = np.column_stack((latitude, longitude))

mapa = folium.Map(zoom_start=3.)
mapa.add_child(plugins.HeatMap(coordenadas))
mapa.save('covid.html')
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Dica:** Para conhecer o pacote Folium veja os links:
# * https://python-visualization.github.io/folium/
# * https://medium.com/@datalivre/folium-d6036a9ad29c

# %% [markdown]
# ### <font color=blue>Nuvem de palavras</font>

# %%
words = ' '.join(tweets_df['Tweets'])

words_clean = " ".join([word for word in words.split()
                            if 'https' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

# %% [markdown]
# **OBSERVAÇÃO:**
# Antes de importar o pacote imread faça a intalação do mesmo.

# %%
import warnings

warnings.simplefilter('ignore')

wc = WordCloud(min_font_size=10, 
               max_font_size=300, 
               background_color='white', 
               mode="RGB",
               width=2000, 
               height=1000,
               normalize_plurals= True).generate(words_clean)

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig('covid_clound.png', dpi=300)
plt.show()

# %% [markdown]
# **Dica:** Para conhecer o pacote WordCloud veja os links:
# * https://amueller.github.io/word_cloud/index.html
# * Exemplos: https://amueller.github.io/word_cloud/auto_examples/index.html#example-gallery

# %%
wc = WordCloud(min_font_size=10, 
               max_font_size=300, 
               background_color='black', #cor de fundo
               mode="RGB",
               width=2000, 
               height=1000,
               normalize_plurals= True).generate(words_clean)

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
#plt.savefig('covid_clound.png', dpi=300)
plt.show()

# %% [markdown]
# #####  Para texto em português, use o exemplo abaixo:

# %%
stopwords= set(STOPWORDS)

new_words = []
with open("stopwords_pt.txt", 'r') as f:
    [new_words.append(word) for line in f for word in line.split()]

new_stopwords = stopwords.union(new_words)

words = ' '.join(tweets_df['Tweets'])

words_clean = " ".join([word for word in words.split()
                            if 'https' not in word
                                and not word.startswith('@')
                                and word != 'RT'
                            ])

warnings.simplefilter('ignore')

wc = WordCloud(min_font_size=10, 
               max_font_size=300, 
               background_color='white', 
               mode="RGB",
               stopwords=new_stopwords,
               width=2000, 
               height=1000,
               normalize_plurals= True).generate(words_clean)

plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.savefig('covid_clound_pt.png', dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-111-1f7fc6182b12> in <module>
#       2
#       3 new_words = []
# ----> 4 with open("stopwords_pt.txt", 'r') as f:
#       5     [new_words.append(word) for line in f for word in line.split()]
#       6
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stopwords_pt.txt'

# %% [markdown]
# ### <font color=blue>Análise temporal dos tweets</font>

# %%
#Tweets postados por dia
data = tweets_df

# %%
print(data['Date'][0])
# Out:
# 2020-06-24 15:09:36

# %%
from datetime import datetime

# %%
#Tweets postados por dia
data = tweets_df

print(data['Date'][0])

data['Date'] = pd.to_datetime(data['Date']).apply(lambda x: x.date())

print(data['Date'][0])
# Out:
# 2020-06-24 15:09:36
# 2020-06-24

# %%
x = data['Date'].value_counts() #conta a quantidade de tweets por dia
x
# Out:
# 2020-06-24    119
# 2020-06-23     90
# 2020-06-17     69
# 2020-06-18     30
# 2020-06-25     12
# 2020-06-21      3
# 2020-06-22      3
# Name: Date, dtype: int64

# %%
tlen = pd.Series(data['Date'].value_counts(), index=data['Date'])

tlen.plot(figsize=(16,4), color='r');

# %% [markdown]
# ## <font color=red>Text Mining com o pacote NLTK</font>
#
# Para conhecer o pacote *NLTK* veja a documentação completa em:
# * https://www.nltk.org/index.html
#
# **Desgustação**

# %%
from nltk.tokenize import TweetTokenizer

tweet_tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

# %%
tweets_tokens = [] #lista para armazenar os tokens

# %%
for tweet in tweets_df['Tweets']:   
    print (tweet_tokenizer.tokenize(tweet))
    tweets_tokens.append(tweet_tokenizer.tokenize(tweet))
# Out:
# ['this', 'woman', 'on', 'the', 'news', 'just', 'said', ',', 'imagine', 'if', 'there', 'was', 'a', 'medication', 'that', 'reduced', 'your', 'chances', 'of', 'getting', 'covid', 'by', '5x', '.', 'everyone', 'would', 'want', 'that', 'medication', '.', 'well', ',', "that's", 'wearing', 'a', 'mask', '.']
# ['numbers', 'are', 'going', 'in', 'the', 'wrong', 'direction', '.', 'yesterday', 'marked', 'the', '3rd', '-', 'highest', 'number', 'of', 'new', 'cases', '(', '34,720', ')', 'reported', 'in', 'one', 'day', 'in', 'the', 'us', 'since', 'the', 'pandemic', 'began', '.', '(', 'higher', '2', 'dates', 'were', 'in', 'april', ')', 'https://t.co/9o9Q5f8pfC']
# ['the', 'trump', 'admin', '.', 'plans', 'to', 'end', 'federal', 'funding', 'and', 'support', 'for', 'coronavirus', 'testing', 'sites', 'at', 'the', 'end', 'of', 'this', 'month', ',', 'has', 'learned', '.', 'https://t.co/6JPPHra2Xk']
# ['breaking', ':', 'trump', 'is', 'ending', 'funding', 'for', '13', 'coronavirus', 'testing', 'sites', 'in', '5', 'states', '.', 'this', 'is', 'an', 'example', 'of', 'trump', 'slowing', 'testing', 'in', 'broad', 'daylight', '.', "it's", 'criminal', '.']
# ['this', 'woman', 'on', 'the', 'news', 'just', 'said', ',', 'imagine', 'if', 'there', 'was', 'a', 'medication', 'that', 'reduced', 'your', 'chances', 'of', 'getting', 'covid', 'by', '5x', '.', 'everyone', 'would', 'want', 'that', 'medication', '.', 'well', ',', "that's", 'wearing', 'a', 'mask', '.']
# ['numbers', 'are', 'going', 'in', 'the', 'wrong', 'direction', '.', 'yesterday', 'marked', 'the', '3rd', '-', 'highest', 'number', 'of', 'new', 'cases', '(', '34,720', ')', 'reported', 'in', 'one', 'day', 'in', 'the', 'us', 'since', 'the', 'pandemic', 'began', '.', '(', 'higher', '2', 'dates', 'were', 'in', 'april', ')', 'https://t.co/9o9Q5f8pfC']
# ['the', 'trump', 'admin', '.', 'plans', 'to', 'end', 'federal', 'funding', 'and', 'support', 'for', 'coronavirus', 'testing', 'sites', 'at', 'the', 'end', 'of', 'this', 'month', ',', 'has', 'learned', '.', 'https://t.co/6JPPHra2Xk']
# ['breaking', ':', 'trump', 'is', 'ending', 'funding', 'for', '13', 'coronavirus', 'testing', 'sites', 'in', '5', 'states', '.', 'this', 'is', 'an', 'example', 'of', 'trump', 'slowing', 'testing', 'in', 'broad', 'daylight', '.', "it's", 'criminal', '.']
# ['yesterday', 'the', 'us', 'hit', 'a', 'record', 'high', 'for', 'new', 'covid', 'cases', '.', 'wear', 'a', 'mask', '.']
# ['the', 'coronavirus', 'is', 'at', 'record', 'numbers', '.', "it's", 'raging', 'out', 'of', 'control', '.', 'where', 'the', 'hell', 'is', 'the', 'federal', 'government', '?', 'where', 'the', 'hell', 'is', 'our', 'national', 'leadership', '?', 'i', 'cannot', 'imagine', 'this', 'level', 'of', 'dereliction', 'of', 'duty', 'in', 'any', 'other', 'administration', 'i', 'have', 'seen', 'in', 'my', '(', 'long', ')', 'lifetime', '.']
# ['how', 'many', 'americans', 'killed', 'by', 'covid', '-', '19', 'would', 'still', 'be', 'alive', 'today', 'if', 'trump', 'hadn', '’', 't', 'politicized', 'wearing', 'a', 'mask', '?']
# ['breaking', 'via', 'wapo', ':', 'dozens', 'of', 'secret', 'service', 'officers', 'and', 'agents', 'on', 'site', 'for', "trump's", 'tulsa', 'rally', 'have', 'been', 'ordered', 'to', 'self-quarantine', 'after', 'two', 'of', 'their', 'colleagues', 'tested', 'positive', 'for', 'coronavirus', '\u2060', '—', 'part', 'of', 'the', 'fallout', 'from', "trump's", 'insistence', 'on', 'the', 'event', '.', 'https://t.co/m1lMO93XLB']
# ['breaking', ':', 'we', 'just', 'filed', 'a', 'complaint', 'on', 'trump', ',', 'the', 'cdc', ',', 'and', 'hhs', 'for', 'intentionally', 'preventing', ',', 'slowing', ',', 'delaying', ',', 'hampering', 'and', 'obstructing', 'testing', 'for', 'coronavirus', 'in', 'the', 'us', '.', 'we', 'are', 'asking', 'the', 'inspector', 'general', 'of', 'hhs', 'to', 'investigate', 'immediately', '.']
# ['new', 'york', ',', 'new', 'jersey', 'and', 'connecticut', 'issued', 'a', 'travel', 'advisory', 'that', 'requires', 'people', 'arriving', 'from', 'states', 'with', 'high', 'coronavirus', 'rates', 'to', 'quarantine', 'for', '14', 'days', 'https://t.co/vFR9i4LdiW']
# ['today', ':', 'trump', 'is', 'doing', 'something', 'about', 'the', 'pandemic', '.', 'today', 'he', '’', 's', 'filing', 'a', 'brief', 'in', 'the', 'supreme', 'court', 'to', 'end', 'the', 'aca', '&', 'take', 'health', 'care', 'coverage', 'away', 'from', '20', 'million', 'people', '.']
# ['breaking', ':', 'us', 'hits', 'single', 'day', 'high', 'of', 'reported', 'coronavirus', 'cases', '.', 'federal', 'government', 'silent', '.']
# ['amid', "america's", '#covid19', 'disaster', ',', 'i', 'must', 'come', 'clean', 'about', 'a', 'lie', 'i', 'spread', 'as', 'a', 'health', 'insurance', 'exec', ':', 'we', 'spent', 'big', '$', '$', 'to', 'push', 'the', 'idea', 'that', "canada's", 'single-payer', 'system', 'was', 'awful', '&', 'the', 'u', '.', 's', '.', 'system', 'much', 'better', '.', 'it', 'was', 'a', 'lie', '&', 'the', 'nations', "'", 'covid', 'responses', 'prove', 'it', '.', 'the', 'truth', ':', '(', '1/6', ')']
# ['covid', '-', '19', 'has', 'gone', 'down', 'due', 'to', 'the', 'efforts', 'of', 'everyone', 'but', 'is', 'still', 'in', 'general', 'circulation', '.', 'if', 'we', 'do', 'not', 'follow', 'social', 'distancing', 'guidance', 'then', 'cases', 'will', 'rise', 'again', '.', 'naturally', 'people', 'will', 'want', 'to', 'enjoy', 'the', 'sun', 'but', 'we', 'need', 'to', 'do', 'so', 'in', 'a', 'way', 'that', 'is', 'safe', 'for', 'all', '.']
# ['workers', 'called', 'back', 'on', 'the', 'job', 'deserve', 'access', 'to', 'regular', ',', 'reliable', 'covid', '-', '19', 'testing', '.']
# ['cities', 'with', 'black', 'lives', 'matter', 'protests', 'have', 'not', 'seen', 'spikes', 'in', 'covid', '-', '19', 'https://t.co/DX3AFrIrpO']
# ['trump', 'calling', 'covid', '-', '19', 'the', '“', 'kung', 'flu', '”', 'is', 'stupid', ',', 'racist', 'and', 'part', 'of', 'the', 'reason', 'he', 'is', 'losing', 'this', 'election', 'in', 'increasingly', 'humiliating', 'fashion', '.', 'his', 'material', 'is', 'no', 'longer', 'effective', 'just', 'self-degrading', '.']
# ['asian', 'americans', 'now', 'make', 'up', '11', '%', 'of', 'the', 'electorate', 'in', 'nv', ',', '5.5', '%', 'in', 'tx', 'and', '4.7', '%', 'in', 'ga', '.', 'so', 'go', 'ahead', 'and', 'keep', 'saying', 'racist', 'stuff', 'like', 'kung', 'flu', '.', 'also', ',', 'you', 'are', 'making', 'fun', 'of', 'a', 'pandemic', 'that', '’', 's', 'killed', 'over', '120,000', 'americans', 'in', 'four', 'months', '.', 'see', 'you', 'in', 'november', '.', 'https://t.co/V9iW6ASOqU']
# ['as', 'per', "patanjali's", 'application', ',', 'we', 'issued', 'them', 'license', '.', 'they', "didn't", 'mention', 'coronavirus', ',', 'we', 'only', 'approved', 'license', 'for', 'immunity', 'booster', ',', 'cough', '&', 'fever', '.', "we'll", 'issue', 'them', 'a', 'notice', 'asking', 'how', 'they', 'got', 'permission', 'to', 'make', 'the', 'kit', '(', 'for', 'covid', '19', '):', 'licence', 'officer', ',', 'uttarakhand', 'ayurved', 'dept', 'https://t.co/I7CWKoJhbK']
# ['excited', 'to', 'announce', 'i', '’', 'm', 'playing', 'in', 'esoccer', 'aid', 'on', 'saturday', '!', '🎮', '⚽', 'for', 'have', 'teamed', 'up', 'with', 'to', 'help', 'stop', 'impact', 'of', 'coronavirus', 'on', 'children', '’', 's', 'lives', 'info', 'here', '👉', 'https://t.co/MztTDSEyPY', 'https://t.co/roht3jrung']
# ['new', ':', 'overflowing', 'hospitals', '.', 'widespread', 'corruption', '.', 'and', 'a', 'chloroquine-obsessed', 'populist', 'in', 'charge', '.', 'the', 'coronavirus', "pandemic's", 'worst-case', 'scenario', 'is', 'unfolding', 'in', 'brazil', '.', 'https://t.co/tIhJ6BtijF']
# ['65,000', 'people', 'have', 'lost', 'their', 'lives', 'to', 'covid', '-', '19', '.', 'the', 'prime', 'minister', "shouldn't", 'reject', 'challenge', 'that', 'could', 'save', 'lives', '.', '#pmqs', 'https://t.co/rLZCAH866Q']
# ['pm', 'can', '’', 't', 'be', 'allowed', 'to', 'get', 'away', 'with', 'this', 'fudging', 'question', 'of', 'why', '*', 'two', 'thirds', '*', 'of', 'those', 'with', 'covid', '-', '19', 'haven', '’', 't', 'been', 'contacted', 'via', 'test', '&', 'trace', 'is', 'so', 'weak', 'so', 'no', ',', 'this', 'is', '*', 'not', '*', '“', 'formidable', 'achievement', '”', '-', 'it', '’', 's', 'a', 'damning', 'indictment', 'on', 'a', 'scheme', 'that', '’', 's', 'far', 'from', '“', 'world', 'beating', '”', '#pmqs']
# ['from', 'the', 'times', '/', 'siena', 'poll', '.', 'i', 'keep', 'seeing', 'claims', 'that', '"', 'americans', '"', "don't", 'have', 'the', 'patience', 'to', 'control', 'the', 'pandemic', '.', 'no', ',', '*', 'republicans', '*', '—', 'taking', 'cues', 'from', 'their', 'leaders', '—', 'are', 'demanding', 'early', 'opening', '.', 'and', "they're", 'in', 'the', 'minority', '1', '/', 'https://t.co/mXim1fRBqy']
# ['alarming', 'spike', 'in', 'coronavirus', 'sparks', 'fears', 'california', 'is', "'", 'starting', 'to', 'lose', 'this', 'battle', "'", 'https://t.co/d2xyyB8qG4']
# ['apparently', ',', 'if', 'you', 'eat', '“', 'tiddi', '”', 'or', 'locust', ',', 'it', 'cures', 'coronavirus', '.', 'if', 'you', 'don', '’', 't', 'have', 'coronavirus', ',', 'it', 'improves', 'immunity', 'against', 'coronavirus', '.', 'serious', 'discussion', 'in', 'pakistan', 'parliament', '.', 'https://t.co/XYJsfURJc3']
# ['i', '’', 'm', '35', '&', 'in', 'decent', 'health', '.', 'having', 'read', 'widely', 'on', 'covid', ',', 'i', '’', 'm', 'not', 'worried', 'about', 'dying', 'from', 'it', '.', 'i', 'am', 'concerned', 'of', 'having', 'long-term', 'health', 'issues', 'that', 'affect', 'quality', 'of', 'life', 'for', 'months', '&', 'years', '.', 'https://t.co/HekullGid5']
# ['just', 'in', ':', 'los', 'angeles', 'county', 'now', 'leading', 'the', 'nation', 'in', 'coronavirus', 'cases', '.', 'https://t.co/8rHCmZ5JiY']
# ['johnson', 'walked', 'into', 'another', 'starmer', 'trap', 'by', 'accusing', 'him', 'of', 'using', 'coronavirus', 'misleading', 'figures', ',', 'the', 'labour', 'leader', 'pointing', 'out', 'they', 'are', 'from', '"', 'cough', '"', 'government', 'briefing', 'slides', '#pmqs']
# ['inept', 'pm', 'responds', 'to', 'accusing', 'him', 'of', 'using', '#coronavirus', 'misleading', 'figures', '.', 'keir', 'points', 'out', 'that', 'they', 'are', 'from', 'governments', 'own', 'briefing', 'slides', '!', '😳', '#pmqs']
# ['media', 'ignores', '90', '%', 'coronavirus', 'death', 'collapse', 'in', 'country', 'https://t.co/mXrsmtMg6P']
# ['there', 'is', 'a', 'sad', 'irony', 'that', 'the', 'same', 'elected', 'officials', 'who', 'refused', 'to', 'listen', 'to', 'science', ',', 'who', 'mocked', 'public', 'health', ',', 'who', 'minimized', 'the', 'coronavirus', ',', 'are', 'desperate', 'for', 'science', 'to', 'bail', 'out', 'their', 'negligence', '(', 'which', 'has', 'led', 'to', 'unnecessary', 'death', 'and', 'suffering', ')', 'with', 'vaccines', 'and', 'treatments', '.']
# ['however', 'these', 'rallies', 'have', 'played', 'out', 'for', 'trump', ',', 'these', 'are', 'still', 'the', 'only', 'indoor', 'events', 'in', 'the', 'country', 'in', 'months', 'where', 'thousands', 'of', 'people', 'have', 'congregated', 'inside', 'the', 'same', 'space', '.', 'how', 'do', 'we', 'explain', 'that', 'in', 'terms', 'of', 'our', 'responsibility', 'as', 'a', 'country', 'in', 'the', 'midst', 'of', 'a', 'global', 'pandemic', '?', 'https://t.co/wqBo7Nc10M']
# ['trump', 'amping', 'up', 'his', 'crowd', 'in', 'phoenix', 'by', 'referring', 'to', 'the', 'coronavirus', 'as', '“', 'kung', 'flu', '”', 'again', '.']
# ['trump', 'quotes', 'mlk', 'on', 'not', 'judging', 'people', 'by', 'the', 'color', 'of', 'their', 'skin', 'minutes', 'after', 'he', 'uses', 'the', 'racist', 'term', '"', 'kung', 'flu', '"', 'to', 'describe', 'the', 'coronavirus', '.']
# ['covid', 'update', 'june', '23', ':', 'trump', 'sees', 'nothing', 'but', 'good', 'news', 'in', 'the', 'coronavirus', '.', 'unlike', 'other', 'world', 'leaders', 'with', 'better', 'health', '&', 'economic', 'results', 'who', 'aim', 'to', 'limit', 'death', '&', 'economic', 'loss', 'with', 'masks', '&', 'other', 'containment', ',', 'trump', '’', 's', 'approach', 'is', 'a', 'mix', 'of', 'lying', ',', 'denial', '&', 'spin', '.', '1', '/']
# ['looks', 'like', 'engel', ',', 'who', 'was', 'famously', 'absent', 'from', 'own', 'district', 'as', 'the', 'covid', 'crisis', 'unfolded', ',', "won't", 'be', 'compelled', 'to', 'visit', 'at', 'all', 'going', 'forward', '.', '😋', 'so', 'excited', 'my', 'mom', 'got', 'a', 'chance', 'to', 'vote', 'for', 'bowman', 'today', '.', 'https://t.co/2csYJDHOXz']
# ['president', 'just', 'pointed', 'out', 'in', 'his', 'phoenix', 'speech', 'that', 'he', 'sent', 'the', 'unsn', 'comfort', 'hospital', 'ship', 'and', 'could', 'have', 'put', 'senior', 'citizens', 'infected', 'with', 'covid', 'on', 'the', 'ship', 'instead', 'of', 'nursing', 'homes', '...', 'instead', 'cuomo', 'murdered', 'senior', 'citizens', 'https://t.co/8rfsa5vSto']
# ['we', 'cannot', 'let', 'covid', '-', '19', 'spread', 'like', 'it', 'is', 'right', 'now', 'in', 'washington', '.', 'so', 'today', ',', 'we', '’', 're', 'mandating', 'facial', 'coverings', 'statewide', '.', 'https://t.co/CL8MWDvKoo']
# ['rebekah', 'jones', 'was', 'fired', 'last', 'month', 'from', 'her', 'job', 'at', 'the', 'florida', 'department', 'of', 'health', '-', 'where', 'she', 'helped', 'create', 'a', 'data', 'portal', 'about', 'the', "state's", 'covid', '-', '19', 'cases', '-', 'after', 'she', 'was', 'asked', 'to', 'manipulate', 'data', '.', 'this', 'is', '...', 'not', 'good', '.', '#flapol', 'https://t.co/QbI7JEg994']
# ['loans', 'worth', 'rs', '75,426', '.', '39', 'crore', 'to', '17.02', 'lakh', 'applicants', 'already', 'sanctioned', 'till', '18', 'june', '2020', 'under', 'the', '100', '%', 'emergency', 'credit', 'line', 'guarantee', 'scheme', 'of', '#aatmanirbharbharatabhiyan', '.', 'the', 'magnitude', 'of', 'such', 'liquidity', 'support', 'to', 'msmes', 'in', 'face', 'of', 'the', 'covid', 'pandemic', 'is', 'unprecedented', '.', 'https://t.co/geyz5qGL9B']
# ['what', 'a', 'coincidence', 'that', 'the', 'us', 'has', 'handled', 'covid', '-', '19', 'worse', 'than', 'just', 'about', 'any', 'government', 'in', 'the', 'world', ',', 'and', 'has', 'a', 'president', 'who', "doesn't", 'know', 'why', "it's", 'called', 'covid', '-', '19', '.', 'https://t.co/ZFCCRThNHY']
# ['former', 'defense', 'secretary', 'and', 'retired', 'marine', 'general', 'jim', 'mattis', 'has', 'appeared', 'in', 'a', 'pandemic', 'public', 'service', 'announcement', 'urging', 'listeners', 'in', 'his', 'hometown', 'to', 'wear', 'face', 'coverings', 'to', 'help', 'prevent', 'coronavirus', '.', 'https://t.co/IO6N4ZHdFN']
# ['universal', 'masking', 'is', 'the', 'most', 'obvious', 'and', 'least', 'intrusive', 'intervention', 'that', 'states', 'with', 'large', 'epidemics', 'can', 'now', 'reach', 'for', '.', 'but', 'it', 'won', '’', 't', 'be', 'enough', 'at', 'this', 'stage', '.', 'fl', ',', 'tx', ',', 'az', ',', 'ca', 'may', 'all', 'have', 'to', 'consider', 'limiting', 'elective', 'surgeries', 'to', 'once', 'again', 'free', 'up', 'hospital', 'capacity', 'for', 'covid', '.', 'https://t.co/TUlB909nsy']
# ['spoke', 'with', 'about', 'what', 'feels', 'increasingly', 'like', 'the', 'federal', 'government', 'giving', 'up', 'on', 'the', 'pandemic', 'we', 'may', 'be', 'done', 'with', 'the', 'pandemic', 'but', 'the', 'pandemic', 'is', 'not', 'done', 'with', 'us', 'we', 'know', 'how', 'to', 'get', 'our', 'arms', 'around', 'this', 'but', 'if', 'we', 'choose', 'not', 'to', 'act', ',', 'our', 'future', 'looks', 'pretty', 'tough', 'https://t.co/sWlk2mwn8g']
# ['breaking', ':', 'the', 'missouri', 'supreme', 'court', 'ruled', 'that', 'our', 'lawsuit', 'to', 'make', 'sure', 'all', 'eligible', 'voters', 'are', 'able', 'to', 'vote', 'by', 'mail', 'without', 'a', 'notary', 'during', 'covid', '-', '19', 'can', 'continue', '.', 'missouri', ',', "we'll", 'see', 'you', 'in', 'court', '.', 'https://t.co/YeSaaVnGGx']
# ['our', 'policy', 'editor', 'lewis', 'goodall', 'has', 'sobering', 'news', 'on', 'deaths', 'in', 'this', 'pandemic', ',', 'particularly', 'in', 'the', 'uk', '’', 's', 'care', 'home', 'sector', ',', 'where', 'excess', 'deaths', 'have', 'increased', 'by', '93', '%', 'during', 'this', 'time', 'and', '13.6', '%', 'of', 'residents', 'died', '.', '|', '#newsnight', 'https://t.co/SajUq5N1ou']
# ['on', 'the', 'worst', 'day', 'of', 'the', 'pandemic', 'in', '#arizona', 'with', '58,179', 'cases', 'and', 'single-day', 'records', 'of', '⚠', '️', '3,593', 'new', 'cases', 'and', '⚠', '️', '42', 'new', 'deaths', ',', 'these', 'unmasked', '#trump', 'supporters', 'at', 'dream', 'city', 'church', ',', 'phoenix', 'arizona', 'are', 'breathing', '#covid', 'in', 'and', 'out', '.', 'https://t.co/EI1Oy4gUiZ']
# ['flash', ':', 'texas', 'posts', 'new', 'covid', 'spike', '—', 'record', '*', '5,489', '*', 'new', 'cases', ',', 'record', '*', '4,092', '*', 'patients', 'in', 'hospital', 'beds']
# ['janice', 'dean', ':', 'new', 'york', 'governor', 'andrew', 'cuomo', 'needs', 'to', 'be', 'investigated', 'for', 'sending', 'recovering', 'covid', 'patients', 'into', 'nursing', 'homes', 'https://t.co/1TgOr5Fwv7']
# ['this', 'is', 'trump', 'speaking', 'right', 'now', 'in', 'arizona', ',', 'where', 'coronavirus', 'cases', 'are', 'spiking', '.', 'hospitals', 'are', 'overrun', '.', 'the', '3,591', 'new', 'cases', 'reported', 'tuesday', 'marks', 'the', 'highest', 'one-day', 'total', 'yet', '.', 'https://t.co/XEFA7PHDCo']
# ['i', 'am', 'amazed', 'that', 'there', "isn't", 'a', 'universal', 'public', 'consensus', 'in', 'the', 'united', 'states', 'that', 'is', 'voiced', 'routinely', 'by', 'elected', 'officials', 'of', 'both', 'parties', 'on', 'major', 'media', 'that', 'the', 'words', ',', 'actions', ',', 'and', 'inaction', 'of', 'donald', 'trump', 'during', 'this', 'pandemic', 'have', 'literally', 'killed', 'tens', 'of', 'thousands', 'of', 'people']
# ['stop', 'letting', 'the', 'media', 'distort', 'the', 'facts', 'surrounding', 'coronavirus', '.', 'the', 'statistics', 'being', 'presented', 'are', 'meant', 'to', 'inspire', 'fear', '&', 'paranoia', '.', 'is', 'doing', 'a', 'great', 'job', '!', 'make', 'sure', 'you', 'rt', 'this', 'video', 'for', 'all', 'to', 'see', 'so', 'they', 'can', 'understand', 'the', 'truth', '!', 'https://t.co/RDVH7AeNI9']
# ['trump', 'says', 'hiding', 'the', 'truth', 'about', 'coronavirus', 'will', 'make', 'it', 'go', 'away', '.', 'kayleigh', 'says', 'he', '’', 's', 'just', 'kidding', '.', 'trump', 'says', 'no', 'way', '.', 'i', 'was', 'dead', 'serious', '.', 'emphasis', 'on', 'the', '“', 'dead', '.', '”']
# ['for', 'republicans', 'who', 'want', 'to', 'constantly', 'bring', 'up', 'the', 'flu', ':', 'according', 'to', 'new', 'cdc', 'data', ',', 'the', 'us', 'influenza', 'death', 'rate', 'is', '.', '1', '%', ',', 'while', 'the', 'covid', '-', '19', 'death', 'rate', 'is', '5.2', '%', '.', 'this', 'means', 'that', 'the', 'average', 'death', 'rate', 'for', 'covid', 'is', 'almost', '50', 'times', 'higher', 'than', 'that', 'of', 'the', 'flu', '.']
# ['"', 'in', 'the', 'last', '14', 'days', ',', 'oregon', 'has', 'reported', 'a', '234', '%', 'jump', 'in', 'infections', ',', 'oklahoma', 'jumped', 'by', '202', '%', ',', "florida's", 'number', 'increased', 'by', '155', '%', ',', 'and', "arizona's", 'confirmed', 'coronavirus', 'cases', 'climbed', 'by', '142', '%', '"', 'https://t.co/eucS7BZ3L5']
# ['meatpacking', 'companies', 'used', 'the', 'covid', '-', '19', 'pandemic', '–', 'and', 'the', 'threat', 'of', 'shortages', '–', 'as', 'cover', 'to', 'jack', 'up', 'prices', '&', 'endanger', 'workers', 'while', 'they', 'exported', 'record', 'amounts', 'of', 'pork', '&', 'other', 'meat', 'products', 'abroad', '.', '&', 'i', 'are', 'opening', 'an', 'investigation', '.', 'https://t.co/WhYPe3ZfVc']
# ['a', 'blockbuster', 'new', 'study', 'finds', 'that', 'overall', ',', 'the', 'federal', 'coronavirus', 'relief', 'package', 'has', 'failed', 'to', 'rescue', 'the', 'businesses', 'and', 'jobs', 'getting', 'hit', 'hardest', 'by', 'the', 'pandemic', '.', 'it', 'also', 'found', 'that', 'state-permitted', 'reopenings', "don't", 'seem', 'to', 'boost', 'the', 'economy', '.', 'https://t.co/y3b7at0UaJ']
# ['new', 'york', 'state', 'is', 'one', 'of', 'only', '3', 'states', 'that', 'are', 'on', 'track', 'to', 'contain', '#covid', '.', 'i', "can't", 'stress', 'enough', 'how', 'important', 'it', 'is', 'that', 'we', "don't", 'blow', 'this', 'incredible', 'progress', 'now', '.', 'wear', 'a', 'mask', '.', 'get', 'tested', '.', 'be', 'smart', '.', '(', 'study', 'by', ')', 'https://t.co/mzSVB0MwQd', 'https://t.co/aKjfZH7UhZ']
# ['breaking', 'news', 'out', 'of', 'miami-dade', 'co', '.', ',', 'fl', '—', 'a', 'major', 'hospital', 'now', 'at', 'capacity', 'amid', 'the', 'big', '#covid__19', 'spike', 'in', 'florida', 'https://t.co/mn0JFPZfxl']
# ['breaking', 'news', ':', 'the', 'eu', 'is', 'prepared', 'to', 'bar', 'american', 'travelers', 'when', 'it', 'reopens', 'its', 'borders', 'on', 'july', '1', 'because', 'the', 'u', '.', 's', '.', 'government', 'has', 'not', 'controlled', 'the', 'coronavirus', ',', 'according', 'to', 'draft', 'lists', 'that', 'would', 'also', 'bar', 'visitors', 'from', 'brazil', 'and', 'russia', '.', 'https://t.co/UOIRziUH0c']
# ['your', 'kentucky', 'election', 'day', 'reminder', 'that', 'mitch', 'mcconnell', 'thinks', 'states', 'bearing', 'the', 'brunt', 'of', 'this', 'pandemic', 'should', 'file', 'for', 'bankruptcy', ',', 'but', 'multibillion-dollar', 'corporations', 'deserve', 'a', '$', '500,000', ',', '000,000', 'bailout', '.']
# ['the', "admin's", 'stated', 'reason', 'that', 'barr', "can't", 'testify', 'before', 'the', 'house', 'is', 'that', 'officials', 'need', 'to', 'focus', 'on', 'fighting', 'the', 'pandemic', ',', 'which', 'is', 'odd', 'since', 'the', 'official', 'actually', 'in', 'charge', 'of', 'fighting', 'the', 'pandemic', ',', 'dr', '.', 'fauci', ',', 'is', 'testifying', 'before', 'the', 'house', 'right', 'now', '.']
# ['breaking', ':', 'rep', 'welch', 'asked', "trump's", 'medical', 'chiefs', 'to', 'raise', 'their', 'hands', 'if', 'they', 'agree', 'with', "trump's", 'statements', 'about', 'coronavirus', 'being', 'like', 'the', 'flu', ',', 'it', 'going', 'away', ',', 'under', 'control', '.', 'over', 'and', 'over', 'again', ',', 'no', 'hands', 'were', 'raised', '.', "trump's", 'own', 'people', '.', 'no', 'hands', 'raised', '.', '#trumpslowstestingwedie']
# ['because', 'of', 'mail-in', 'ballots', ',', '2020', 'will', 'be', 'the', 'most', 'rigged', 'election', 'in', 'our', 'nations', 'history', '-', 'unless', 'this', 'stupidity', 'is', 'ended', '.', 'we', 'voted', 'during', 'world', 'war', 'one', '&', 'world', 'war', 'two', 'with', 'no', 'problem', ',', 'but', 'now', 'they', 'are', 'using', 'covid', 'in', 'order', 'to', 'cheat', 'by', 'using', 'mail-ins', '!']
# ['want', 'to', 'practice', 'your', 'first', 'and', 'second', 'amendment', 'rights', 'during', 'the', 'pandemic', '?', 'too', 'bad', '.', 'want', 'to', 'riot', 'in', 'the', 'streets', 'during', 'the', 'pandemic', '?', 'no', 'problem', '!', 'https://t.co/nIu8fngUcg']
# ['trump', 'contradicts', 'his', 'own', 'aides', 'and', 'says', 'he', 'was', 'not', 'kidding', 'when', 'he', 'said', 'he', 'asked', 'for', 'a', 'slowdown', 'in', 'coronavirus', 'testing', ':', '“', 'i', 'don', '’', 't', 'kid', ',', 'let', 'me', 'just', 'tell', 'you', '.', '”']
# ["it's", 'worth', 'repeating', 'that', 'this', 'weekend', ',', 'president', 'trump', 'admitted', 'he', 'directed', 'his', 'administration', 'to', 'slow', 'down', 'coronavirus', 'testing', 'in', 'the', 'middle', 'of', 'a', 'global', 'pandemic', '.', 'he', 'continues', 'to', 'prove', 'just', 'how', 'unfit', 'he', 'is', 'to', 'lead', 'our', 'nation', '.']
# ['if', 'you', 'think', 'wearing', 'a', 'mask', '“', 'cuts', 'off', 'your', 'oxygen', '"', ',', 'just', 'wait', 'until', 'you', 'find', 'out', 'what', 'covid', 'does', '.']
# ['again', ',', '120,000', 'americans', 'are', 'dead', 'from', 'covid', '-', '19', 'and', 'the', 'president', 'ordered', 'testing', 'to', 'be', 'slowed', 'down', 'because', 'big', 'numbers', 'would', 'hurt', 'him', 'politically', '.', 'there', "aren't", 'words', 'for', 'this', 'level', 'of', 'betrayal', '.', 'https://t.co/v2fvnqdmcU']
# ['we', 'did', 'a', 'great', 'job', 'on', 'coronavirus', ',', 'including', 'the', 'very', 'early', 'ban', 'on', 'china', ',', 'ventilator', 'production', ',', 'and', 'testing', ',', 'which', 'is', 'by', 'far', 'the', 'most', ',', 'and', 'best', ',', 'in', 'the', 'world', '.', 'we', 'saved', 'millions', 'of', 'u', '.', 's', '.', 'lives', '.', '!', 'yet', 'the', 'fake', 'news', 'refuses', 'to', 'acknowledge', 'this', 'in', 'a', 'positive', 'way', '.', 'but', 'they', 'do', 'give', '...']
# ['the', 'e', '.', 'u', '.', 'is', 'prepared', 'to', 'bar', 'american', 'travelers', 'when', 'it', 'reopens', 'borders', 'july', '1', 'because', 'the', 'u', '.', 's', '.', 'has', 'not', 'controlled', 'the', 'coronavirus', ',', 'according', 'to', 'draft', 'lists', '.', 'https://t.co/Q9wIoZBnSx']
# ['actually', 'you', 'just', 'got', 'rocked', 'by', 'teens', 'on', 'tiktok', 'who', 'flooded', 'the', 'trump', 'campaign', 'w', '/', 'fake', 'ticket', 'reservations', '&', 'tricked', 'you', 'into', 'believing', 'a', 'million', 'people', 'wanted', 'your', 'white', 'supremacist', 'open', 'mic', 'enough', 'to', 'pack', 'an', 'arena', 'during', 'covid', 'shout', 'out', 'to', 'zoomers', '.', 'y', '’', 'all', 'make', 'me', 'so', 'proud', '.', '☺', '️', 'https://t.co/jGrp5bSZ9T']
# ['dear', 'kejriwal', 'ji', ',', 'it', 'has', 'already', 'been', 'decided', 'in', 'our', 'meeting', '3', 'days', 'back', 'and', 'mha', 'has', 'assigned', 'the', 'work', 'of', 'operating', 'the', '10,000', 'bed', 'covid', 'care', 'centre', 'at', 'radha', 'swami', 'beas', 'in', 'delhi', 'to', 'itbp', '.', 'the', 'work', 'is', 'in', 'full', 'swing', 'and', 'a', 'large', 'part', 'of', 'the', 'facility', 'will', 'be', 'operational', 'by', '26th', 'jun', '.', 'https://t.co/VLMOQdEseY']
# ['the', 'white', 'house', 'has', 'taken', 'down', 'the', 'tents', 'where', 'people', 'who', 'were', 'entering', 'used', 'to', 'have', 'to', 'be', 'tested', 'for', 'covid', 'symptoms', '.', 'the', 'strategy', 'is', 'clear', ':', 'pretend', 'the', 'pandemic', 'is', 'gone', ',', 'and', 'our', 'covid', 'crisis', 'will', 'be', 'over', '.', 'truth', 'be', 'damned', '.', 'it', '’', 's', 'idiotic', 'and', 'suicidal', '.']
# ['the', 'left', 'is', 'really', 'panicked', 'about', 'the', 'economy', 'coming', 'back', '.', 'ruins', 'their', 'narrative', '.', 'expect', 'more', 'calls', 'to', 'shutdown', 'states', 'again', 'citing', 'supposed', 'covid', 'concerns', '.', 'no', 'tax', 'dollars', 'to', 'states', 'that', 'refuse', 'to', 'open', '.']
# ['just', 'because', 'some', 'people', 'and', 'news', 'outlets', 'have', 'moved', 'on', 'from', 'coronavirus', 'doesn', '’', 't', 'mean', 'the', 'virus', 'is', 'gone', '.', 'we', 'are', 'still', 'in', 'the', 'midst', 'of', 'a', 'deadly', 'pandemic', 'that', 'has', 'claimed', 'more', 'than', '116,000', 'american', 'lives', '.', 'wear', 'a', 'mask', '.']
# ['it', '’', 's', 'weird', 'watching', 'people', 'just', 'decide', 'the', 'pandemic', 'is', 'over']
# ['breaking', ':', 'trump', 'just', 'lied', 'on', 'hannity', 'saying', 'coronavirus', 'doesn', '’', 't', 'effect', 'young', 'people', '.', 'it', '’', 's', 'an', 'impeachable', 'lie', '.']
# ['vice', 'president', 'pence', 'claimed', 'success', 'because', 'covid', '-', '19', 'deaths', 'are', '“', 'down', 'to', '”', 'fewer', 'than', '750', 'a', 'day', '.', "that's", 'more', 'than', '20,000', 'a', 'month', '—', 'and', "they're", 'self-congratulating', '?', 'unbelievable', '.', 'it', 'may', 'be', 'good', 'enough', 'for', 'president', 'trump', ',', 'but', 'it', 'will', 'never', 'be', 'acceptable', 'if', 'i', 'am', 'president', '.', 'https://t.co/9h08nxjC6k']
# ['the', 'governor', 'has', 'informed', 'local', 'officials', 'that', 'if', 'citizens', 'are', 'required', 'to', 'wear', 'masks', 'in', 'public', 'buildings', ',', 'their', 'governments', 'will', 'not', 'receive', 'any', 'of', 'the', '$', '100', 'million', 'in', 'federal', 'coronavirus', 'aid', 'money', '.', 'https://t.co/jKi68KbIni']
# ['if', '80', '%', 'of', 'americans', 'wore', 'masks', ',', 'covid', '-', '19', 'infections', 'would', 'plummet', ',', 'new', 'study', 'says', 'https://t.co/4oDvKO9oyq', 'via']
# ['updated', 'info', '|', 'gov', '.', 'ron', 'desantis', 'said', '260', 'workers', 'at', 'the', 'orlando', 'international', 'airport', 'have', 'tested', 'positive', 'for', 'the', 'coronavirus', 'after', 'nearly', '500', 'employees', 'were', 'tested', '.', 'https://t.co/tfiAN6MRtx']
# ['arizona', 'sheriff', 'who', 'refused', 'to', 'enforce', 'lockdown', 'now', 'has', 'covid', '-', '19', 'https://t.co/txezR5Vvlp']
# ['the', 'sheriff', 'of', 'pinal', 'county', ',', 'arizona', 'has', 'announced', 'that', 'he', 'tested', 'positive', 'for', 'coronavirus', ',', 'a', 'day', 'after', 'visiting', 'the', 'white', 'house', '.', 'https://t.co/AvjkDAkHoA']
# ['bolton', '’', 's', 'book', 'revealing', 'a', 'fumbling', ',', 'bumbling', ',', 'angry', ',', 'corrupt', ',', 'racist', ',', 'vengeful', ',', 'and', 'ignorant', 'president', '..', 'a', 'president', 'with', 'a', 'personality', 'poised', 'to', 'botch', 'a', 'coming', 'pandemic', ',', 'much', 'of', 'which', 'could', 'have', 'been', 'mitigated', 'by', 'listening', 'to', 'simple', 'science-my', 'question-why', 'did', 'he', 'wait', 'to', 'share', '?']
# ['if', 'i', 'wear', 'a', 'mask', 'i', 'lower', 'my', 'chances', 'of', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'if', 'you', 'wear', 'a', 'mask', ',', 'you', 'lower', 'your', 'chances', 'of', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'if', 'we', 'both', 'wear', 'masks', '.', 'neither', 'of', 'us', 'is', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'you', 'know', '.', 'rocket', 'science', '.']
# ['all', 'the', 'depression', 'experts', 'yesterday', ',', 'who', 'were', 'the', 'covid', 'experts', 'day', 'before', ',', 'are', 'today', 'defence', 'and', 'warfare', 'experts', '🙏', '#humanityrip']
# ['just', 'thinking', 'about', 'the', 'nurses', 'wearing', 'garbage', 'bags', ',', 'and', 'using', 'the', 'same', 'masks', 'over', '&', 'over', 'in', 'ny', 'during', 'the', 'worst', 'of', 'the', 'pandemic', ',', 'or', 'public', 'school', 'teachers', 'being', 'disparaged', '&', 'denigrated', 'in', 'public', 'discourse', '&', 'having', 'to', 'buy', 'their', 'own', 'supplies', ',', 'and', 'still', 'showing', 'up', 'to', 'do', 'their', 'jobs', '.', 'https://t.co/RdXrgAG4uK']
# ['so', 'let', 'me', 'get', 'this', 'straight', ':', 'we', "can't", 'find', 'the', 'money', 'to', 'extend', 'unemployment', 'benefits', 'during', 'a', 'pandemic', ',', 'but', 'we', 'spend', '$', '115,000', ',', '000,000', 'a', 'year', 'on', 'police', '?']
# ['the', 'media', 'has', 'amplified', 'the', 'voices', 'of', 'fear', 'and', 'panic', '.', 'they', 'are', 'using', 'covid', '-', '19', 'to', 'push', 'other', 'agendas', '.', 'please', 'retweet', 'this', 'and', 'follow', 'my', 'account', 'as', 'i', 'am', 'spreading', 'facts', 'and', 'science', '.', 'we', 'need', 'to', 'amplify', 'it', 'together', 'we', 'can', 'get', 'back', 'to', 'normal', '.', 'and', 'i', 'mean', 'normal', ',', 'not', 'a', '“', 'new', 'normal', '”', '.']
# ['"', 'she', 'will', 'never', 'see', 'her', 'daughter', 'grow', '"', 'nurse', 'mary', 'agyapong', 'was', 'heavily', 'pregnant', 'when', 'she', 'died', 'with', 'coronavirus', ',', 'doctors', 'managed', 'to', 'save', 'her', 'baby', 'her', 'husband', 'says', 'she', "shouldn't", 'have', 'been', 'working', 'at', 'the', 'hospital', 'during', 'the', 'pandemic', 'https://t.co/v4UVdYJM2x', 'https://t.co/aJmz22xxjT']
# ['trump', '’', 's', 'coronavirus', 'coverup', 'is', 'the', 'biggest', 'scandal', 'in', 'american', 'history', '.']
# ['”', 'these', 'outbreaks', 'are', 'manifestations', 'of', 'our', 'dangerously', 'unbalanced', 'relationship', 'with', 'nature', '”', '.', 'pandemics', 'like', 'covid', '19', 'are', 'a', 'result', 'from', 'destruction', 'of', 'nature', 'according', 'to', 'un', 'and', 'who', '.', 'https://t.co/17vEJYO6t5']
# ['good', 'morning', '!', '☕', 'a', 'federal', 'judge', 'has', 'ordered', 'treasury', 'secretary', 'steven', 'mnuchin', 'to', 'give', 'tribes', 'hundreds', 'of', 'millions', 'of', 'dollars', 'in', 'emergency', 'covid', '-', '19', 'relief', 'funds', 'they', 'should', 'have', 'gotten', 'months', 'ago', '.', 'https://t.co/BY8TjNgJLV']
# ['history', 'will', 'treat', 'elected', 'officials', 'who', 'ban', 'masks', 'like', 'the', 'fools', 'they', 'are', '.', 'school', 'children', 'will', 'study', 'how', 'the', 'president', '&', 'people', 'like', 'governor', 'abbott', 'make', 'the', 'pandemic', 'worse', 'than', 'it', 'needed', 'to', 'be', '&', 'let', 'citizens', 'needlessly', 'die', '.', 'https://t.co/ewb8iTL239']
# ['access', 'tools', 'for', 'transformation', '!', '#innerengineeringonline', 'is', 'a', 'powerful', '7', '-', 'session', 'course', 'with', 'sadhguru', '.', 'offered', 'free', 'for', 'covid', 'warriors', 'and', 'at', '50', '%', 'for', 'challenging', 'times', '.', 'take', 'the', 'course', 'in', 'your', 'own', 'space', ',', 'at', 'your', 'own', 'pace', 'at', ':', 'https://t.co/QlLszUzyZi', 'https://t.co/vScbCmL9Lt']
# ['politicians', 'must', 'stop', 'protecting', 'social', 'media', 'billionaires', 'who', 'are', 'given', 'a', 'free', 'pass', 'while', 'putting', 'american', 'democracy', 'at', 'risk', '.', 'facebook', 'promotes', 'extremist', 'groups', 'that', 'kill', 'federal', 'officials', 'and', 'fuels', 'conspiracies', 'that', 'could', 'spread', 'covid', '-', '19', '.', '#abolish230', 'https://t.co/K36krPgmu5']
# ['overheard', ':', 'has', 'covid', '-', '19', 'forced', 'you', 'to', 'wear', 'a', 'mask', 'and', 'glasses', 'at', 'the', 'same', 'time', '?', 'you', 'may', 'be', 'entitled', 'to', 'condensation', '.']
# ['u', '.', 's', '.', 'vs', '.', 'e', '.', 'u', '.', 'on', 'confirmed', 'covid', '-', '19', 'cases', 'https://t.co/ZL4DU10p8q']
# ['covid', 'outbreaks', 'in', 'selected', 'states', 'continue', 'to', 'expand', '.', 'according', 'to', 'the', 'covid', 'tracking', 'project', ',', 'fl', ',', 'tx', ',', 'and', 'az', 'had', 'the', 'largest', 'confirmed', 'case', 'increases', 'to', 'date', '.', 'https://t.co/9DOACH3dtz']
# ['target', 'is', 'raising', 'its', 'starting', 'wage', 'to', '$', '15', 'an', 'hour', ',', 'making', 'it', 'the', 'first', 'major', 'retailer', 'to', 'permanently', 'increase', 'pay', 'during', 'the', 'pandemic', 'https://t.co/8Np1CY0DuX']
# ['"', 'mnuchin', 'is', 'at', 'the', 'core', 'of', 'the', 'trump', 'crime', 'cabal', 'along', 'with', 'kushner', ',', 'pence', 'and', 'a', 'few', 'others', '.', 'as', 'predicted', ',', 'they', 'are', 'using', 'the', 'tragedy', 'of', 'the', 'coronavirus', 'as', 'pretext', 'for', 'a', 'massive', 'kleptocratic', 'heist', '.', '"', '-', '-', 'https://t.co/3a7hOE2Koy']
# ['if', 'only', 'we', 'had', 'a', 'coronavirus', 'task', 'force', 'https://t.co/1jLTXhct3v']
# ['i', 'wouldn', '’', 't', 'accuse', 'trump', 'of', 'actually', '*', 'wanting', '*', 'more', 'people', 'to', 'get', 'sick', 'and', 'die', '.', 'but', 'he', 'must', 'know', ',', 'despite', 'his', 'stupidity', ',', 'that', 'what', 'he', 'and', 'pence', 'are', 'saying', 'and', 'doing', 'will', 'certainly', 'have', 'that', 'result', '.', 'that', 'makes', 'their', 'conduct', 'not', 'just', 'monstrous', 'but', 'criminal', '.', 'https://t.co/BbO7rmEGX8']
# ['seriously', 'how', 'do', 'we', 'have', 'a', 'pandemic', 'that', 'is', 'worse', 'in', 'europe', 'than', 'in', 'asia', 'and', 'worse', 'in', 'the', 'usa', 'than', 'in', 'europe', 'and', 'still', 'people', 'are', 'saying', 'the', 'key', 'variables', 'are', 'density', 'and', 'transit', 'usage', '?']
# ['.', 'is', 'investing', 'in', 'covid', '-', '19', 'research', ',', 'and', 'in', 'israeli', 'banks', 'financing', 'israeli', 'apartheid', '.', 'apartheid', 'heightens', 'palestinians', "'", 'covid', '-', '19', 'risk', '.', 'join', 'thomas', 'from', 'in', 'telling', 'axa', 'to', 'support', 'human', 'rights', 'for', 'all', 'by', 'divesting', 'from', 'apartheid', ':', 'https://t.co/0t0p3mQ5yb', 'https://t.co/DlpEjqvYNQ']
# ['this', 'woman', 'on', 'the', 'news', 'just', 'said', ',', 'imagine', 'if', 'there', 'was', 'a', 'medication', 'that', 'reduced', 'your', 'chances', 'of', 'getting', 'covid', 'by', '5x', '.', 'everyone', 'would', 'want', 'that', 'medication', '.', 'well', ',', "that's", 'wearing', 'a', 'mask', '.']
# ['numbers', 'are', 'going', 'in', 'the', 'wrong', 'direction', '.', 'yesterday', 'marked', 'the', '3rd', '-', 'highest', 'number', 'of', 'new', 'cases', '(', '34,720', ')', 'reported', 'in', 'one', 'day', 'in', 'the', 'us', 'since', 'the', 'pandemic', 'began', '.', '(', 'higher', '2', 'dates', 'were', 'in', 'april', ')', 'https://t.co/9o9Q5f8pfC']
# ['the', 'trump', 'admin', '.', 'plans', 'to', 'end', 'federal', 'funding', 'and', 'support', 'for', 'coronavirus', 'testing', 'sites', 'at', 'the', 'end', 'of', 'this', 'month', ',', 'has', 'learned', '.', 'https://t.co/6JPPHra2Xk']
# ['breaking', ':', 'trump', 'is', 'ending', 'funding', 'for', '13', 'coronavirus', 'testing', 'sites', 'in', '5', 'states', '.', 'this', 'is', 'an', 'example', 'of', 'trump', 'slowing', 'testing', 'in', 'broad', 'daylight', '.', "it's", 'criminal', '.']
# ['yesterday', 'the', 'us', 'hit', 'a', 'record', 'high', 'for', 'new', 'covid', 'cases', '.', 'wear', 'a', 'mask', '.']
# ['the', 'coronavirus', 'is', 'at', 'record', 'numbers', '.', "it's", 'raging', 'out', 'of', 'control', '.', 'where', 'the', 'hell', 'is', 'the', 'federal', 'government', '?', 'where', 'the', 'hell', 'is', 'our', 'national', 'leadership', '?', 'i', 'cannot', 'imagine', 'this', 'level', 'of', 'dereliction', 'of', 'duty', 'in', 'any', 'other', 'administration', 'i', 'have', 'seen', 'in', 'my', '(', 'long', ')', 'lifetime', '.']
# ['how', 'many', 'americans', 'killed', 'by', 'covid', '-', '19', 'would', 'still', 'be', 'alive', 'today', 'if', 'trump', 'hadn', '’', 't', 'politicized', 'wearing', 'a', 'mask', '?']
# ['breaking', 'via', 'wapo', ':', 'dozens', 'of', 'secret', 'service', 'officers', 'and', 'agents', 'on', 'site', 'for', "trump's", 'tulsa', 'rally', 'have', 'been', 'ordered', 'to', 'self-quarantine', 'after', 'two', 'of', 'their', 'colleagues', 'tested', 'positive', 'for', 'coronavirus', '\u2060', '—', 'part', 'of', 'the', 'fallout', 'from', "trump's", 'insistence', 'on', 'the', 'event', '.', 'https://t.co/m1lMO93XLB']
# ['breaking', ':', 'we', 'just', 'filed', 'a', 'complaint', 'on', 'trump', ',', 'the', 'cdc', ',', 'and', 'hhs', 'for', 'intentionally', 'preventing', ',', 'slowing', ',', 'delaying', ',', 'hampering', 'and', 'obstructing', 'testing', 'for', 'coronavirus', 'in', 'the', 'us', '.', 'we', 'are', 'asking', 'the', 'inspector', 'general', 'of', 'hhs', 'to', 'investigate', 'immediately', '.']
# ['new', 'york', ',', 'new', 'jersey', 'and', 'connecticut', 'issued', 'a', 'travel', 'advisory', 'that', 'requires', 'people', 'arriving', 'from', 'states', 'with', 'high', 'coronavirus', 'rates', 'to', 'quarantine', 'for', '14', 'days', 'https://t.co/vFR9i4LdiW']
# ['today', ':', 'trump', 'is', 'doing', 'something', 'about', 'the', 'pandemic', '.', 'today', 'he', '’', 's', 'filing', 'a', 'brief', 'in', 'the', 'supreme', 'court', 'to', 'end', 'the', 'aca', '&', 'take', 'health', 'care', 'coverage', 'away', 'from', '20', 'million', 'people', '.']
# ['breaking', ':', 'us', 'hits', 'single', 'day', 'high', 'of', 'reported', 'coronavirus', 'cases', '.', 'federal', 'government', 'silent', '.']
# ['amid', "america's", '#covid19', 'disaster', ',', 'i', 'must', 'come', 'clean', 'about', 'a', 'lie', 'i', 'spread', 'as', 'a', 'health', 'insurance', 'exec', ':', 'we', 'spent', 'big', '$', '$', 'to', 'push', 'the', 'idea', 'that', "canada's", 'single-payer', 'system', 'was', 'awful', '&', 'the', 'u', '.', 's', '.', 'system', 'much', 'better', '.', 'it', 'was', 'a', 'lie', '&', 'the', 'nations', "'", 'covid', 'responses', 'prove', 'it', '.', 'the', 'truth', ':', '(', '1/6', ')']
# ['covid', '-', '19', 'has', 'gone', 'down', 'due', 'to', 'the', 'efforts', 'of', 'everyone', 'but', 'is', 'still', 'in', 'general', 'circulation', '.', 'if', 'we', 'do', 'not', 'follow', 'social', 'distancing', 'guidance', 'then', 'cases', 'will', 'rise', 'again', '.', 'naturally', 'people', 'will', 'want', 'to', 'enjoy', 'the', 'sun', 'but', 'we', 'need', 'to', 'do', 'so', 'in', 'a', 'way', 'that', 'is', 'safe', 'for', 'all', '.']
# ['workers', 'called', 'back', 'on', 'the', 'job', 'deserve', 'access', 'to', 'regular', ',', 'reliable', 'covid', '-', '19', 'testing', '.']
# ['cities', 'with', 'black', 'lives', 'matter', 'protests', 'have', 'not', 'seen', 'spikes', 'in', 'covid', '-', '19', 'https://t.co/DX3AFrIrpO']
# ['trump', 'calling', 'covid', '-', '19', 'the', '“', 'kung', 'flu', '”', 'is', 'stupid', ',', 'racist', 'and', 'part', 'of', 'the', 'reason', 'he', 'is', 'losing', 'this', 'election', 'in', 'increasingly', 'humiliating', 'fashion', '.', 'his', 'material', 'is', 'no', 'longer', 'effective', 'just', 'self-degrading', '.']
# ['asian', 'americans', 'now', 'make', 'up', '11', '%', 'of', 'the', 'electorate', 'in', 'nv', ',', '5.5', '%', 'in', 'tx', 'and', '4.7', '%', 'in', 'ga', '.', 'so', 'go', 'ahead', 'and', 'keep', 'saying', 'racist', 'stuff', 'like', 'kung', 'flu', '.', 'also', ',', 'you', 'are', 'making', 'fun', 'of', 'a', 'pandemic', 'that', '’', 's', 'killed', 'over', '120,000', 'americans', 'in', 'four', 'months', '.', 'see', 'you', 'in', 'november', '.', 'https://t.co/V9iW6ASOqU']
# ['as', 'per', "patanjali's", 'application', ',', 'we', 'issued', 'them', 'license', '.', 'they', "didn't", 'mention', 'coronavirus', ',', 'we', 'only', 'approved', 'license', 'for', 'immunity', 'booster', ',', 'cough', '&', 'fever', '.', "we'll", 'issue', 'them', 'a', 'notice', 'asking', 'how', 'they', 'got', 'permission', 'to', 'make', 'the', 'kit', '(', 'for', 'covid', '19', '):', 'licence', 'officer', ',', 'uttarakhand', 'ayurved', 'dept', 'https://t.co/I7CWKoJhbK']
# ['excited', 'to', 'announce', 'i', '’', 'm', 'playing', 'in', 'esoccer', 'aid', 'on', 'saturday', '!', '🎮', '⚽', 'for', 'have', 'teamed', 'up', 'with', 'to', 'help', 'stop', 'impact', 'of', 'coronavirus', 'on', 'children', '’', 's', 'lives', 'info', 'here', '👉', 'https://t.co/MztTDSEyPY', 'https://t.co/roht3jrung']
# ['new', ':', 'overflowing', 'hospitals', '.', 'widespread', 'corruption', '.', 'and', 'a', 'chloroquine-obsessed', 'populist', 'in', 'charge', '.', 'the', 'coronavirus', "pandemic's", 'worst-case', 'scenario', 'is', 'unfolding', 'in', 'brazil', '.', 'https://t.co/tIhJ6BtijF']
# ['65,000', 'people', 'have', 'lost', 'their', 'lives', 'to', 'covid', '-', '19', '.', 'the', 'prime', 'minister', "shouldn't", 'reject', 'challenge', 'that', 'could', 'save', 'lives', '.', '#pmqs', 'https://t.co/rLZCAH866Q']
# ['pm', 'can', '’', 't', 'be', 'allowed', 'to', 'get', 'away', 'with', 'this', 'fudging', 'question', 'of', 'why', '*', 'two', 'thirds', '*', 'of', 'those', 'with', 'covid', '-', '19', 'haven', '’', 't', 'been', 'contacted', 'via', 'test', '&', 'trace', 'is', 'so', 'weak', 'so', 'no', ',', 'this', 'is', '*', 'not', '*', '“', 'formidable', 'achievement', '”', '-', 'it', '’', 's', 'a', 'damning', 'indictment', 'on', 'a', 'scheme', 'that', '’', 's', 'far', 'from', '“', 'world', 'beating', '”', '#pmqs']
# ['from', 'the', 'times', '/', 'siena', 'poll', '.', 'i', 'keep', 'seeing', 'claims', 'that', '"', 'americans', '"', "don't", 'have', 'the', 'patience', 'to', 'control', 'the', 'pandemic', '.', 'no', ',', '*', 'republicans', '*', '—', 'taking', 'cues', 'from', 'their', 'leaders', '—', 'are', 'demanding', 'early', 'opening', '.', 'and', "they're", 'in', 'the', 'minority', '1', '/', 'https://t.co/mXim1fRBqy']
# ['alarming', 'spike', 'in', 'coronavirus', 'sparks', 'fears', 'california', 'is', "'", 'starting', 'to', 'lose', 'this', 'battle', "'", 'https://t.co/d2xyyB8qG4']
# ['apparently', ',', 'if', 'you', 'eat', '“', 'tiddi', '”', 'or', 'locust', ',', 'it', 'cures', 'coronavirus', '.', 'if', 'you', 'don', '’', 't', 'have', 'coronavirus', ',', 'it', 'improves', 'immunity', 'against', 'coronavirus', '.', 'serious', 'discussion', 'in', 'pakistan', 'parliament', '.', 'https://t.co/XYJsfURJc3']
# ['i', '’', 'm', '35', '&', 'in', 'decent', 'health', '.', 'having', 'read', 'widely', 'on', 'covid', ',', 'i', '’', 'm', 'not', 'worried', 'about', 'dying', 'from', 'it', '.', 'i', 'am', 'concerned', 'of', 'having', 'long-term', 'health', 'issues', 'that', 'affect', 'quality', 'of', 'life', 'for', 'months', '&', 'years', '.', 'https://t.co/HekullGid5']
# ['just', 'in', ':', 'los', 'angeles', 'county', 'now', 'leading', 'the', 'nation', 'in', 'coronavirus', 'cases', '.', 'https://t.co/8rHCmZ5JiY']
# ['johnson', 'walked', 'into', 'another', 'starmer', 'trap', 'by', 'accusing', 'him', 'of', 'using', 'coronavirus', 'misleading', 'figures', ',', 'the', 'labour', 'leader', 'pointing', 'out', 'they', 'are', 'from', '"', 'cough', '"', 'government', 'briefing', 'slides', '#pmqs']
# ['inept', 'pm', 'responds', 'to', 'accusing', 'him', 'of', 'using', '#coronavirus', 'misleading', 'figures', '.', 'keir', 'points', 'out', 'that', 'they', 'are', 'from', 'governments', 'own', 'briefing', 'slides', '!', '😳', '#pmqs']
# ['media', 'ignores', '90', '%', 'coronavirus', 'death', 'collapse', 'in', 'country', 'https://t.co/mXrsmtMg6P']
# ['there', 'is', 'a', 'sad', 'irony', 'that', 'the', 'same', 'elected', 'officials', 'who', 'refused', 'to', 'listen', 'to', 'science', ',', 'who', 'mocked', 'public', 'health', ',', 'who', 'minimized', 'the', 'coronavirus', ',', 'are', 'desperate', 'for', 'science', 'to', 'bail', 'out', 'their', 'negligence', '(', 'which', 'has', 'led', 'to', 'unnecessary', 'death', 'and', 'suffering', ')', 'with', 'vaccines', 'and', 'treatments', '.']
# ['however', 'these', 'rallies', 'have', 'played', 'out', 'for', 'trump', ',', 'these', 'are', 'still', 'the', 'only', 'indoor', 'events', 'in', 'the', 'country', 'in', 'months', 'where', 'thousands', 'of', 'people', 'have', 'congregated', 'inside', 'the', 'same', 'space', '.', 'how', 'do', 'we', 'explain', 'that', 'in', 'terms', 'of', 'our', 'responsibility', 'as', 'a', 'country', 'in', 'the', 'midst', 'of', 'a', 'global', 'pandemic', '?', 'https://t.co/wqBo7Nc10M']
# ['trump', 'amping', 'up', 'his', 'crowd', 'in', 'phoenix', 'by', 'referring', 'to', 'the', 'coronavirus', 'as', '“', 'kung', 'flu', '”', 'again', '.']
# ['trump', 'quotes', 'mlk', 'on', 'not', 'judging', 'people', 'by', 'the', 'color', 'of', 'their', 'skin', 'minutes', 'after', 'he', 'uses', 'the', 'racist', 'term', '"', 'kung', 'flu', '"', 'to', 'describe', 'the', 'coronavirus', '.']
# ['covid', 'update', 'june', '23', ':', 'trump', 'sees', 'nothing', 'but', 'good', 'news', 'in', 'the', 'coronavirus', '.', 'unlike', 'other', 'world', 'leaders', 'with', 'better', 'health', '&', 'economic', 'results', 'who', 'aim', 'to', 'limit', 'death', '&', 'economic', 'loss', 'with', 'masks', '&', 'other', 'containment', ',', 'trump', '’', 's', 'approach', 'is', 'a', 'mix', 'of', 'lying', ',', 'denial', '&', 'spin', '.', '1', '/']
# ['looks', 'like', 'engel', ',', 'who', 'was', 'famously', 'absent', 'from', 'own', 'district', 'as', 'the', 'covid', 'crisis', 'unfolded', ',', "won't", 'be', 'compelled', 'to', 'visit', 'at', 'all', 'going', 'forward', '.', '😋', 'so', 'excited', 'my', 'mom', 'got', 'a', 'chance', 'to', 'vote', 'for', 'bowman', 'today', '.', 'https://t.co/2csYJDHOXz']
# ['president', 'just', 'pointed', 'out', 'in', 'his', 'phoenix', 'speech', 'that', 'he', 'sent', 'the', 'unsn', 'comfort', 'hospital', 'ship', 'and', 'could', 'have', 'put', 'senior', 'citizens', 'infected', 'with', 'covid', 'on', 'the', 'ship', 'instead', 'of', 'nursing', 'homes', '...', 'instead', 'cuomo', 'murdered', 'senior', 'citizens', 'https://t.co/8rfsa5vSto']
# ['we', 'cannot', 'let', 'covid', '-', '19', 'spread', 'like', 'it', 'is', 'right', 'now', 'in', 'washington', '.', 'so', 'today', ',', 'we', '’', 're', 'mandating', 'facial', 'coverings', 'statewide', '.', 'https://t.co/CL8MWDvKoo']
# ...
# ['breaking', 'news', 'out', 'of', 'miami-dade', 'co', '.', ',', 'fl', '—', 'a', 'major', 'hospital', 'now', 'at', 'capacity', 'amid', 'the', 'big', '#covid__19', 'spike', 'in', 'florida', 'https://t.co/mn0JFPZfxl']
# ['breaking', 'news', ':', 'the', 'eu', 'is', 'prepared', 'to', 'bar', 'american', 'travelers', 'when', 'it', 'reopens', 'its', 'borders', 'on', 'july', '1', 'because', 'the', 'u', '.', 's', '.', 'government', 'has', 'not', 'controlled', 'the', 'coronavirus', ',', 'according', 'to', 'draft', 'lists', 'that', 'would', 'also', 'bar', 'visitors', 'from', 'brazil', 'and', 'russia', '.', 'https://t.co/UOIRziUH0c']
# ['your', 'kentucky', 'election', 'day', 'reminder', 'that', 'mitch', 'mcconnell', 'thinks', 'states', 'bearing', 'the', 'brunt', 'of', 'this', 'pandemic', 'should', 'file', 'for', 'bankruptcy', ',', 'but', 'multibillion-dollar', 'corporations', 'deserve', 'a', '$', '500,000', ',', '000,000', 'bailout', '.']
# ['the', "admin's", 'stated', 'reason', 'that', 'barr', "can't", 'testify', 'before', 'the', 'house', 'is', 'that', 'officials', 'need', 'to', 'focus', 'on', 'fighting', 'the', 'pandemic', ',', 'which', 'is', 'odd', 'since', 'the', 'official', 'actually', 'in', 'charge', 'of', 'fighting', 'the', 'pandemic', ',', 'dr', '.', 'fauci', ',', 'is', 'testifying', 'before', 'the', 'house', 'right', 'now', '.']
# ['breaking', ':', 'rep', 'welch', 'asked', "trump's", 'medical', 'chiefs', 'to', 'raise', 'their', 'hands', 'if', 'they', 'agree', 'with', "trump's", 'statements', 'about', 'coronavirus', 'being', 'like', 'the', 'flu', ',', 'it', 'going', 'away', ',', 'under', 'control', '.', 'over', 'and', 'over', 'again', ',', 'no', 'hands', 'were', 'raised', '.', "trump's", 'own', 'people', '.', 'no', 'hands', 'raised', '.', '#trumpslowstestingwedie']
# ['because', 'of', 'mail-in', 'ballots', ',', '2020', 'will', 'be', 'the', 'most', 'rigged', 'election', 'in', 'our', 'nations', 'history', '-', 'unless', 'this', 'stupidity', 'is', 'ended', '.', 'we', 'voted', 'during', 'world', 'war', 'one', '&', 'world', 'war', 'two', 'with', 'no', 'problem', ',', 'but', 'now', 'they', 'are', 'using', 'covid', 'in', 'order', 'to', 'cheat', 'by', 'using', 'mail-ins', '!']
# ['want', 'to', 'practice', 'your', 'first', 'and', 'second', 'amendment', 'rights', 'during', 'the', 'pandemic', '?', 'too', 'bad', '.', 'want', 'to', 'riot', 'in', 'the', 'streets', 'during', 'the', 'pandemic', '?', 'no', 'problem', '!', 'https://t.co/nIu8fngUcg']
# ['trump', 'contradicts', 'his', 'own', 'aides', 'and', 'says', 'he', 'was', 'not', 'kidding', 'when', 'he', 'said', 'he', 'asked', 'for', 'a', 'slowdown', 'in', 'coronavirus', 'testing', ':', '“', 'i', 'don', '’', 't', 'kid', ',', 'let', 'me', 'just', 'tell', 'you', '.', '”']
# ["it's", 'worth', 'repeating', 'that', 'this', 'weekend', ',', 'president', 'trump', 'admitted', 'he', 'directed', 'his', 'administration', 'to', 'slow', 'down', 'coronavirus', 'testing', 'in', 'the', 'middle', 'of', 'a', 'global', 'pandemic', '.', 'he', 'continues', 'to', 'prove', 'just', 'how', 'unfit', 'he', 'is', 'to', 'lead', 'our', 'nation', '.']
# ['if', 'you', 'think', 'wearing', 'a', 'mask', '“', 'cuts', 'off', 'your', 'oxygen', '"', ',', 'just', 'wait', 'until', 'you', 'find', 'out', 'what', 'covid', 'does', '.']
# ['again', ',', '120,000', 'americans', 'are', 'dead', 'from', 'covid', '-', '19', 'and', 'the', 'president', 'ordered', 'testing', 'to', 'be', 'slowed', 'down', 'because', 'big', 'numbers', 'would', 'hurt', 'him', 'politically', '.', 'there', "aren't", 'words', 'for', 'this', 'level', 'of', 'betrayal', '.', 'https://t.co/v2fvnqdmcU']
# ['we', 'did', 'a', 'great', 'job', 'on', 'coronavirus', ',', 'including', 'the', 'very', 'early', 'ban', 'on', 'china', ',', 'ventilator', 'production', ',', 'and', 'testing', ',', 'which', 'is', 'by', 'far', 'the', 'most', ',', 'and', 'best', ',', 'in', 'the', 'world', '.', 'we', 'saved', 'millions', 'of', 'u', '.', 's', '.', 'lives', '.', '!', 'yet', 'the', 'fake', 'news', 'refuses', 'to', 'acknowledge', 'this', 'in', 'a', 'positive', 'way', '.', 'but', 'they', 'do', 'give', '...']
# ['the', 'e', '.', 'u', '.', 'is', 'prepared', 'to', 'bar', 'american', 'travelers', 'when', 'it', 'reopens', 'borders', 'july', '1', 'because', 'the', 'u', '.', 's', '.', 'has', 'not', 'controlled', 'the', 'coronavirus', ',', 'according', 'to', 'draft', 'lists', '.', 'https://t.co/Q9wIoZBnSx']
# ['actually', 'you', 'just', 'got', 'rocked', 'by', 'teens', 'on', 'tiktok', 'who', 'flooded', 'the', 'trump', 'campaign', 'w', '/', 'fake', 'ticket', 'reservations', '&', 'tricked', 'you', 'into', 'believing', 'a', 'million', 'people', 'wanted', 'your', 'white', 'supremacist', 'open', 'mic', 'enough', 'to', 'pack', 'an', 'arena', 'during', 'covid', 'shout', 'out', 'to', 'zoomers', '.', 'y', '’', 'all', 'make', 'me', 'so', 'proud', '.', '☺', '️', 'https://t.co/jGrp5bSZ9T']
# ['dear', 'kejriwal', 'ji', ',', 'it', 'has', 'already', 'been', 'decided', 'in', 'our', 'meeting', '3', 'days', 'back', 'and', 'mha', 'has', 'assigned', 'the', 'work', 'of', 'operating', 'the', '10,000', 'bed', 'covid', 'care', 'centre', 'at', 'radha', 'swami', 'beas', 'in', 'delhi', 'to', 'itbp', '.', 'the', 'work', 'is', 'in', 'full', 'swing', 'and', 'a', 'large', 'part', 'of', 'the', 'facility', 'will', 'be', 'operational', 'by', '26th', 'jun', '.', 'https://t.co/VLMOQdEseY']
# ['the', 'white', 'house', 'has', 'taken', 'down', 'the', 'tents', 'where', 'people', 'who', 'were', 'entering', 'used', 'to', 'have', 'to', 'be', 'tested', 'for', 'covid', 'symptoms', '.', 'the', 'strategy', 'is', 'clear', ':', 'pretend', 'the', 'pandemic', 'is', 'gone', ',', 'and', 'our', 'covid', 'crisis', 'will', 'be', 'over', '.', 'truth', 'be', 'damned', '.', 'it', '’', 's', 'idiotic', 'and', 'suicidal', '.']
# ['the', 'left', 'is', 'really', 'panicked', 'about', 'the', 'economy', 'coming', 'back', '.', 'ruins', 'their', 'narrative', '.', 'expect', 'more', 'calls', 'to', 'shutdown', 'states', 'again', 'citing', 'supposed', 'covid', 'concerns', '.', 'no', 'tax', 'dollars', 'to', 'states', 'that', 'refuse', 'to', 'open', '.']
# ['just', 'because', 'some', 'people', 'and', 'news', 'outlets', 'have', 'moved', 'on', 'from', 'coronavirus', 'doesn', '’', 't', 'mean', 'the', 'virus', 'is', 'gone', '.', 'we', 'are', 'still', 'in', 'the', 'midst', 'of', 'a', 'deadly', 'pandemic', 'that', 'has', 'claimed', 'more', 'than', '116,000', 'american', 'lives', '.', 'wear', 'a', 'mask', '.']
# ['it', '’', 's', 'weird', 'watching', 'people', 'just', 'decide', 'the', 'pandemic', 'is', 'over']
# ['breaking', ':', 'trump', 'just', 'lied', 'on', 'hannity', 'saying', 'coronavirus', 'doesn', '’', 't', 'effect', 'young', 'people', '.', 'it', '’', 's', 'an', 'impeachable', 'lie', '.']
# ['vice', 'president', 'pence', 'claimed', 'success', 'because', 'covid', '-', '19', 'deaths', 'are', '“', 'down', 'to', '”', 'fewer', 'than', '750', 'a', 'day', '.', "that's", 'more', 'than', '20,000', 'a', 'month', '—', 'and', "they're", 'self-congratulating', '?', 'unbelievable', '.', 'it', 'may', 'be', 'good', 'enough', 'for', 'president', 'trump', ',', 'but', 'it', 'will', 'never', 'be', 'acceptable', 'if', 'i', 'am', 'president', '.', 'https://t.co/9h08nxjC6k']
# ['the', 'governor', 'has', 'informed', 'local', 'officials', 'that', 'if', 'citizens', 'are', 'required', 'to', 'wear', 'masks', 'in', 'public', 'buildings', ',', 'their', 'governments', 'will', 'not', 'receive', 'any', 'of', 'the', '$', '100', 'million', 'in', 'federal', 'coronavirus', 'aid', 'money', '.', 'https://t.co/jKi68KbIni']
# ['if', '80', '%', 'of', 'americans', 'wore', 'masks', ',', 'covid', '-', '19', 'infections', 'would', 'plummet', ',', 'new', 'study', 'says', 'https://t.co/4oDvKO9oyq', 'via']
# ['updated', 'info', '|', 'gov', '.', 'ron', 'desantis', 'said', '260', 'workers', 'at', 'the', 'orlando', 'international', 'airport', 'have', 'tested', 'positive', 'for', 'the', 'coronavirus', 'after', 'nearly', '500', 'employees', 'were', 'tested', '.', 'https://t.co/tfiAN6MRtx']
# ['arizona', 'sheriff', 'who', 'refused', 'to', 'enforce', 'lockdown', 'now', 'has', 'covid', '-', '19', 'https://t.co/txezR5Vvlp']
# ['the', 'sheriff', 'of', 'pinal', 'county', ',', 'arizona', 'has', 'announced', 'that', 'he', 'tested', 'positive', 'for', 'coronavirus', ',', 'a', 'day', 'after', 'visiting', 'the', 'white', 'house', '.', 'https://t.co/AvjkDAkHoA']
# ['bolton', '’', 's', 'book', 'revealing', 'a', 'fumbling', ',', 'bumbling', ',', 'angry', ',', 'corrupt', ',', 'racist', ',', 'vengeful', ',', 'and', 'ignorant', 'president', '..', 'a', 'president', 'with', 'a', 'personality', 'poised', 'to', 'botch', 'a', 'coming', 'pandemic', ',', 'much', 'of', 'which', 'could', 'have', 'been', 'mitigated', 'by', 'listening', 'to', 'simple', 'science-my', 'question-why', 'did', 'he', 'wait', 'to', 'share', '?']
# ['if', 'i', 'wear', 'a', 'mask', 'i', 'lower', 'my', 'chances', 'of', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'if', 'you', 'wear', 'a', 'mask', ',', 'you', 'lower', 'your', 'chances', 'of', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'if', 'we', 'both', 'wear', 'masks', '.', 'neither', 'of', 'us', 'is', 'getting', ',', 'or', 'giving', ',', 'covid', '.', 'you', 'know', '.', 'rocket', 'science', '.']
# ['all', 'the', 'depression', 'experts', 'yesterday', ',', 'who', 'were', 'the', 'covid', 'experts', 'day', 'before', ',', 'are', 'today', 'defence', 'and', 'warfare', 'experts', '🙏', '#humanityrip']
# ['just', 'thinking', 'about', 'the', 'nurses', 'wearing', 'garbage', 'bags', ',', 'and', 'using', 'the', 'same', 'masks', 'over', '&', 'over', 'in', 'ny', 'during', 'the', 'worst', 'of', 'the', 'pandemic', ',', 'or', 'public', 'school', 'teachers', 'being', 'disparaged', '&', 'denigrated', 'in', 'public', 'discourse', '&', 'having', 'to', 'buy', 'their', 'own', 'supplies', ',', 'and', 'still', 'showing', 'up', 'to', 'do', 'their', 'jobs', '.', 'https://t.co/RdXrgAG4uK']
# ['so', 'let', 'me', 'get', 'this', 'straight', ':', 'we', "can't", 'find', 'the', 'money', 'to', 'extend', 'unemployment', 'benefits', 'during', 'a', 'pandemic', ',', 'but', 'we', 'spend', '$', '115,000', ',', '000,000', 'a', 'year', 'on', 'police', '?']
# ['the', 'media', 'has', 'amplified', 'the', 'voices', 'of', 'fear', 'and', 'panic', '.', 'they', 'are', 'using', 'covid', '-', '19', 'to', 'push', 'other', 'agendas', '.', 'please', 'retweet', 'this', 'and', 'follow', 'my', 'account', 'as', 'i', 'am', 'spreading', 'facts', 'and', 'science', '.', 'we', 'need', 'to', 'amplify', 'it', 'together', 'we', 'can', 'get', 'back', 'to', 'normal', '.', 'and', 'i', 'mean', 'normal', ',', 'not', 'a', '“', 'new', 'normal', '”', '.']
# ['"', 'she', 'will', 'never', 'see', 'her', 'daughter', 'grow', '"', 'nurse', 'mary', 'agyapong', 'was', 'heavily', 'pregnant', 'when', 'she', 'died', 'with', 'coronavirus', ',', 'doctors', 'managed', 'to', 'save', 'her', 'baby', 'her', 'husband', 'says', 'she', "shouldn't", 'have', 'been', 'working', 'at', 'the', 'hospital', 'during', 'the', 'pandemic', 'https://t.co/v4UVdYJM2x', 'https://t.co/aJmz22xxjT']
# ['trump', '’', 's', 'coronavirus', 'coverup', 'is', 'the', 'biggest', 'scandal', 'in', 'american', 'history', '.']
# ['”', 'these', 'outbreaks', 'are', 'manifestations', 'of', 'our', 'dangerously', 'unbalanced', 'relationship', 'with', 'nature', '”', '.', 'pandemics', 'like', 'covid', '19', 'are', 'a', 'result', 'from', 'destruction', 'of', 'nature', 'according', 'to', 'un', 'and', 'who', '.', 'https://t.co/17vEJYO6t5']
# ['good', 'morning', '!', '☕', 'a', 'federal', 'judge', 'has', 'ordered', 'treasury', 'secretary', 'steven', 'mnuchin', 'to', 'give', 'tribes', 'hundreds', 'of', 'millions', 'of', 'dollars', 'in', 'emergency', 'covid', '-', '19', 'relief', 'funds', 'they', 'should', 'have', 'gotten', 'months', 'ago', '.', 'https://t.co/BY8TjNgJLV']
# ['history', 'will', 'treat', 'elected', 'officials', 'who', 'ban', 'masks', 'like', 'the', 'fools', 'they', 'are', '.', 'school', 'children', 'will', 'study', 'how', 'the', 'president', '&', 'people', 'like', 'governor', 'abbott', 'make', 'the', 'pandemic', 'worse', 'than', 'it', 'needed', 'to', 'be', '&', 'let', 'citizens', 'needlessly', 'die', '.', 'https://t.co/ewb8iTL239']
# ['access', 'tools', 'for', 'transformation', '!', '#innerengineeringonline', 'is', 'a', 'powerful', '7', '-', 'session', 'course', 'with', 'sadhguru', '.', 'offered', 'free', 'for', 'covid', 'warriors', 'and', 'at', '50', '%', 'for', 'challenging', 'times', '.', 'take', 'the', 'course', 'in', 'your', 'own', 'space', ',', 'at', 'your', 'own', 'pace', 'at', ':', 'https://t.co/QlLszUzyZi', 'https://t.co/vScbCmL9Lt']
# ['politicians', 'must', 'stop', 'protecting', 'social', 'media', 'billionaires', 'who', 'are', 'given', 'a', 'free', 'pass', 'while', 'putting', 'american', 'democracy', 'at', 'risk', '.', 'facebook', 'promotes', 'extremist', 'groups', 'that', 'kill', 'federal', 'officials', 'and', 'fuels', 'conspiracies', 'that', 'could', 'spread', 'covid', '-', '19', '.', '#abolish230', 'https://t.co/K36krPgmu5']
# ['overheard', ':', 'has', 'covid', '-', '19', 'forced', 'you', 'to', 'wear', 'a', 'mask', 'and', 'glasses', 'at', 'the', 'same', 'time', '?', 'you', 'may', 'be', 'entitled', 'to', 'condensation', '.']
# ['u', '.', 's', '.', 'vs', '.', 'e', '.', 'u', '.', 'on', 'confirmed', 'covid', '-', '19', 'cases', 'https://t.co/ZL4DU10p8q']
# ['covid', 'outbreaks', 'in', 'selected', 'states', 'continue', 'to', 'expand', '.', 'according', 'to', 'the', 'covid', 'tracking', 'project', ',', 'fl', ',', 'tx', ',', 'and', 'az', 'had', 'the', 'largest', 'confirmed', 'case', 'increases', 'to', 'date', '.', 'https://t.co/9DOACH3dtz']
# ['target', 'is', 'raising', 'its', 'starting', 'wage', 'to', '$', '15', 'an', 'hour', ',', 'making', 'it', 'the', 'first', 'major', 'retailer', 'to', 'permanently', 'increase', 'pay', 'during', 'the', 'pandemic', 'https://t.co/8Np1CY0DuX']
# ['"', 'mnuchin', 'is', 'at', 'the', 'core', 'of', 'the', 'trump', 'crime', 'cabal', 'along', 'with', 'kushner', ',', 'pence', 'and', 'a', 'few', 'others', '.', 'as', 'predicted', ',', 'they', 'are', 'using', 'the', 'tragedy', 'of', 'the', 'coronavirus', 'as', 'pretext', 'for', 'a', 'massive', 'kleptocratic', 'heist', '.', '"', '-', '-', 'https://t.co/3a7hOE2Koy']
# ['if', 'only', 'we', 'had', 'a', 'coronavirus', 'task', 'force', 'https://t.co/1jLTXhct3v']
# ['i', 'wouldn', '’', 't', 'accuse', 'trump', 'of', 'actually', '*', 'wanting', '*', 'more', 'people', 'to', 'get', 'sick', 'and', 'die', '.', 'but', 'he', 'must', 'know', ',', 'despite', 'his', 'stupidity', ',', 'that', 'what', 'he', 'and', 'pence', 'are', 'saying', 'and', 'doing', 'will', 'certainly', 'have', 'that', 'result', '.', 'that', 'makes', 'their', 'conduct', 'not', 'just', 'monstrous', 'but', 'criminal', '.', 'https://t.co/BbO7rmEGX8']
# ['seriously', 'how', 'do', 'we', 'have', 'a', 'pandemic', 'that', 'is', 'worse', 'in', 'europe', 'than', 'in', 'asia', 'and', 'worse', 'in', 'the', 'usa', 'than', 'in', 'europe', 'and', 'still', 'people', 'are', 'saying', 'the', 'key', 'variables', 'are', 'density', 'and', 'transit', 'usage', '?']
# ['.', 'is', 'investing', 'in', 'covid', '-', '19', 'research', ',', 'and', 'in', 'israeli', 'banks', 'financing', 'israeli', 'apartheid', '.', 'apartheid', 'heightens', 'palestinians', "'", 'covid', '-', '19', 'risk', '.', 'join', 'thomas', 'from', 'in', 'telling', 'axa', 'to', 'support', 'human', 'rights', 'for', 'all', 'by', 'divesting', 'from', 'apartheid', ':', 'https://t.co/0t0p3mQ5yb', 'https://t.co/DlpEjqvYNQ']
# ['this', 'woman', 'on', 'the', 'news', 'just', 'said', ',', 'imagine', 'if', 'there', 'was', 'a', 'medication', 'that', 'reduced', 'your', 'chances', 'of', 'getting', 'covid', 'by', '5x', '.', 'everyone', 'would', 'want', 'that', 'medication', '.', 'well', ',', "that's", 'wearing', 'a', 'mask', '.']

# %% [markdown]
# #### Limpar tokens

# %%
from nltk.corpus import stopwords 
import string
 
#punctuation = list(string.punctuation)
stopwords_english = stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\JoaoLott/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\lib\\nltk_data'
#     - 'C:\\Users\\JoaoLott\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-122-40e843c64544> in <module>
#       3
#       4 #punctuation = list(string.punctuation)
# ----> 5 stopwords_english = stopwords.words('english')
#
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     121             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     122
# --> 123         self.__load()
#     124         # This looks circular, but its not, since __load() changes our
#     125         # __class__ to something new:
#
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\corpus\util.py in __load(self)
#      86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
# ---> 88                     raise e
#      89
#      90         # Load the corpus.
#
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\corpus\util.py in __load(self)
#      81         else:
#      82             try:
# ---> 83                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      84             except LookupError as e:
#      85                 try:
#
# C:\ProgramData\Anaconda3\envs\Dev\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     699     sep = '*' * 70
#     700     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 701     raise LookupError(resource_not_found)
#     702
#     703
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\JoaoLott/nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\share\\nltk_data'
#     - 'C:\\ProgramData\\Anaconda3\\envs\\Dev\\lib\\nltk_data'
#     - 'C:\\Users\\JoaoLott\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
def clean_tweets(tweet):
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
 
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
 
    # remove hyperlinks
    tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)
 
    tweets_clean = []    
    for word in tweet_tokens:
        if (word not in stopwords_english and # remove stopwords
                word not in string.punctuation): # remove punctuation
            tweets_clean.append(word)
 
    return tweets_clean

# %%
clean_tweets_tokens = [] #lista para armazenar os tokens

# %%
for tweet in tweets_df['Tweets']:   
    print (clean_tweets(tweet))
    clean_tweets_tokens.append(clean_tweets(tweet))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-125-9351f75bea39> in <module>
#       1 for tweet in tweets_df['Tweets']:
# ----> 2     print (clean_tweets(tweet))
#       3     clean_tweets_tokens.append(clean_tweets(tweet))
#
# <ipython-input-123-836cd32c6e2a> in clean_tweets(tweet)
#      19     tweets_clean = []
#      20     for word in tweet_tokens:
# ---> 21         if (word not in stopwords_english and # remove stopwords
#      22                 word not in string.punctuation): # remove punctuation
#      23             tweets_clean.append(word)
#
# NameError: name 'stopwords_english' is not defined

# %% [markdown]
# Fim!
